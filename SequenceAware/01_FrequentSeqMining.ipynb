# %% [markdown]
# ### Load data and build matrices

# %%
cd ../../../../
# Out:
# /Users/archnnj/Development/recsys/recsys_polimi_challenge_2018/repo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
# %matplotlib inline
import scipy.sparse as sps
from scipy.stats import iqr

import src.utils.build_icm as build_icm
from src.utils.data_splitter import train_test_holdout, train_test_user_holdout, train_test_row_holdout

# %%
import sys
sys.path.append("src/libs/RecSys_Course_2018/") # go to parent dir

# %%
from SequenceAware.sars_tutorial_master.util.data_utils import create_seq_db_filter_top_k, sequences_to_spfm_format
from SequenceAware.sars_tutorial_master.util.split import last_session_out_split
from SequenceAware.sars_tutorial_master.util.metrics import precision, recall, mrr
from SequenceAware.sars_tutorial_master.util import evaluation
from SequenceAware.sars_tutorial_master.recommenders.FSMRecommender import FSMRecommender

# %% [markdown]
# #### Global vars

# %%
JUPYTER = False

# %% [markdown]
# #### Load data

# %%
if JUPYTER:
    # Jupyter
    tracks_csv_file = "../../../data/tracks.csv"
    interactions_csv_file = "../../../data/train.csv"
    playlist_id_csv_file = "../../../data/target_playlists.csv"
    sequential_csv_file = "../../../data/train_sequential.csv"
else:
    # PyCharm
    tracks_csv_file = "data/tracks.csv"
    interactions_csv_file = "data/train.csv"
    playlist_id_csv_file = "data/target_playlists.csv"
    sequential_csv_file = "data/train_sequential.csv"

tracks_df = pd.read_csv(tracks_csv_file)
interactions_df = pd.read_csv(interactions_csv_file)
playlist_id_df = pd.read_csv(playlist_id_csv_file)
train_sequential_df = pd.read_csv(sequential_csv_file)

userList = interactions_df["playlist_id"]
itemList = interactions_df["track_id"]
ratingList = np.ones(interactions_df.shape[0])
targetsList = playlist_id_df["playlist_id"]
targetsListOrdered = targetsList[:5000].tolist()
targetsListCasual = targetsList[5000:].tolist()

userList_unique = pd.unique(userList)
itemList_unique = tracks_df["track_id"]
numUsers = len(userList_unique)
numItems = len(itemList_unique)
numberInteractions = interactions_df.size

# %%
URM_all = sps.coo_matrix((ratingList, (userList, itemList)))
URM_all_csr = URM_all.tocsr()

# %%
itemPopularity = (URM_all>0).sum(axis=0)
itemPopularity = np.array(itemPopularity).squeeze()
itemPopularity_unsorted = itemPopularity
itemPopularity = np.sort(itemPopularity)

# %% [markdown]
# #### Prepare ICM and URM with splits

# %% [raw]
# # Build ICM
# ICM_all = build_icm.build_icm(tracks_df, split_duration_lenght=800, feature_weights={'albums': 1, 'artists': 0.5, 'durations': 0.1})
#
# IDF_ENABLED = True
#
# if IDF_ENABLED:
#     num_tot_items = ICM_all.shape[0]
#     # let's count how many items have a certain feature
#     items_per_feature = (ICM_all > 0).sum(axis=0)
#     IDF = np.array(np.log(num_tot_items / items_per_feature))[0]
#     ICM_idf = ICM_all.copy()
#     # compute the number of non-zeros in each col
#     # NOTE: this works only if X is instance of sparse.csc_matrix
#     col_nnz = np.diff(sps.csc_matrix(ICM_idf).indptr)
#     # then normalize the values in each col
#     ICM_idf.data *= np.repeat(IDF, col_nnz)
#     ICM_all = ICM_idf  # use IDF features
#
# # #### Build URM
#
# URM_all = sps.coo_matrix((ratingList, (userList, itemList)))
# URM_all_csr = URM_all.tocsr()
#
# URM_IDF_ENABLED = False
#
# if URM_IDF_ENABLED:
#     num_tot_items = URM_all.shape[0]
#     # let's count how many items have a certain feature
#     items_per_feature = (URM_all > 0).sum(axis=0)
#     IDF = np.array(np.log(num_tot_items / items_per_feature))[0]
#     URM_idf = URM_all.copy()
#     # compute the number of non-zeros in each col
#     # NOTE: this works only if X is instance of sparse.csc_matrix
#     col_nnz = np.diff(sps.csc_matrix(URM_idf).indptr)
#     # then normalize the values in each col
#     URM_idf.data *= np.repeat(IDF, col_nnz)
#     URM_all = URM_idf  # use IDF features
#
# # #### Train/test split: ratings and user holdout
#
# seed = 0
# # ratings holdout
# # URM_train, URM_test_pred = train_test_holdout(URM_all, train_perc=0.8, seed=seed)
# # URM_valid=URM_test_pred
# # URM_test_known = None
#
# # user holdout
# # URM_train, URM_test_known, URM_test_pred = train_test_user_holdout(URM_all, user_perc=0.8, train_perc=0.8, seed=seed)
#
# # row holdout
# URM_train, URM_test_pred = train_test_row_holdout(URM_all, userList_unique, train_sequential_df, train_perc=0.8, seed=seed, targetsListOrdered=targetsListOrdered, nnz_threshold=10)
# URM_test_known = None
#
# # row holdout - validation
# # URM_train_val, URM_test_pred = train_test_row_holdout(URM_all, userList_unique, train_sequential_df, train_perc=0.8,
# #                                                       seed=seed, targetsListOrdered=targetsListOrdered,
# #                                                       nnz_threshold=10)
# # URM_train, URM_valid = train_test_holdout(URM_train_val, train_perc=0.7, seed=seed)
# # URM_test_known = None
# # URM_train, URM_valid_test_pred = train_test_row_holdout(URM_all, userList_unique, train_sequential_df,
# #                                                        train_perc=0.6,
# #                                                        seed=seed, targetsListOrdered=targetsListOrdered,
# #                                                        nnz_threshold=2)
# # URM_valid, URM_test_pred = train_test_row_holdout(URM_valid_test_pred, userList_unique, train_sequential_df,
# #                                                   train_perc=0.5,
# #                                                  seed=seed, targetsListOrdered=targetsListOrdered,
# #                                                  nnz_threshold=1)
#
# URM_train = URM_train
# #URM_validation = URM_valid
# URM_test = URM_test_pred

# %% [raw]
# import pickle
#
# with open('dump_URM_train', 'wb') as dump_file:
#     pickle.dump(URM_train, dump_file)
# with open('dump_URM_test', 'wb') as dump_file:
#     pickle.dump(URM_test, dump_file)

# %%
import pickle

with open('dump_URM_train', 'rb') as dump_file:
    URM_train = pickle.load(dump_file)
with open('dump_URM_test', 'rb') as dump_file:
    URM_test = pickle.load(dump_file)

# %% [raw]
# ### Utils

# %% [raw]
# def get_sequences_df(URM, train_sequential_df, user_arr):
#     sequences_arr = []
#     for user_id in user_arr:
#         URM_start_pos = URM.indptr[user_id]
#         URM_end_pos = URM.indptr[user_id + 1]
#         user_nnz = URM_end_pos - URM_start_pos
#
#         original_order_items = np.array(
#             train_sequential_df.loc[train_sequential_df['playlist_id'].isin([user_id])]['track_id'])
#         original_order_items = np.array([i for i in original_order_items if i in URM.indices[URM_start_pos:URM_end_pos]]) # filter items in urm
#         # original_order_items_sorted_i = original_order_items.argsort()
#         sequences_arr.append({'user_id':user_id, 'sequence': original_order_items.tolist()})
#     sequences = pd.DataFrame(sequences_arr)
#     sequences = sequences[['user_id', 'sequence']]
#     return sequences

# %% [raw]
# #### Create Sequence

# %% [raw]
# sequences = get_sequences_df(URM_all.tocsr(), train_sequential_df, targetsListOrdered)
# train_sequences = get_sequences_df(URM_train, train_sequential_df, targetsListOrdered)
# test_sequences = get_sequences_df(URM_test, train_sequential_df, targetsListOrdered)

# %% [raw]
# import pickle
#
# with open('dump_sequences', 'wb') as dump_file:
#     pickle.dump(sequences, dump_file)
# with open('dump_train_sequences', 'wb') as dump_file:
#     pickle.dump(train_sequences, dump_file)
# with open('dump_test_sequences', 'wb') as dump_file:
#     pickle.dump(test_sequences, dump_file)

# %% [raw]
# import pickle
#
# with open('dump_sequences', 'rb') as dump_file:
#     sequences = pickle.load(dump_file)
# with open('dump_train_sequences', 'rb') as dump_file:
#     train_sequences = pickle.load(dump_file)
# with open('dump_test_sequences', 'rb') as dump_file:
#     test_sequences = pickle.load(dump_file)

# %% [raw]
# sequences.head()

# %% [raw]
# train_sequences.head()

# %% [raw]
# test_sequences.head()

# %% [raw]
# #### Start of original notebook

# %% [raw]
# dataset = sequences

# %% [raw]
# Let's see at how the dataset looks like

# %% [raw]
# dataset.head()

# %% [raw]
# Let's show ssome statistics about the dataset

# %% [raw]
# from collections import Counter
# cnt = Counter()
# dataset.sequence.map(cnt.update);

# %% [raw]
# sequence_length = dataset.sequence.map(len).values
# n_sessions_per_user = dataset.groupby('user_id').size()
#
# print('Number of items: {}'.format(len(cnt)))
# print('Number of users: {}'.format(dataset.user_id.nunique()))
# print('Number of sessions: {}'.format(len(dataset)) )
#
# print('\nSession length:\n\tAverage: {:.2f}\n\tMedian: {}\n\tMin: {}\n\tMax: {}'.format(
#     sequence_length.mean(),
#     np.quantile(sequence_length, 0.5),
#     sequence_length.min(),
#     sequence_length.max()))
#
# print('Sessions per user:\n\tAverage: {:.2f}\n\tMedian: {}\n\tMin: {}\n\tMax: {}'.format(
#     n_sessions_per_user.mean(),
#     np.quantile(n_sessions_per_user, 0.5),
#     n_sessions_per_user.min(),
#     n_sessions_per_user.max()))

# %% [raw]
# print('Most popular items: {}'.format(cnt.most_common(5)))

# %% [raw]
# <a id='split_the_dataset'></a>

# %% [raw]
# # 2. Split the dataset

# %% [raw]
# For simplicity, let's split the dataset by assigning the **last session** of every user to the **test set**, and **all the previous** ones to the **training set**.

# %% [raw]
# train_data = train_sequences
# test_data = test_sequences

# %% [raw]
# <a id='fitting'></a>

# %% [markdown]
# # 3. Fitting the recommender
#
# Here we fit the recommedation algorithm over the sessions in the training set.
#
# This algorithm extract Frequent Sequential Patterns from all the training sequences. Patterns are having support lower than `minsup` are discarded (support = # occurrences of a pattern in the traning data).
# Recommendations are then generated by looking for patterns having a _prefix_ corresponding to the last `[max_context, min_context]` elements in the user profile, taken in order. Matches are then sorted by decreasing _confidence_ score (ratio between the support of the matched rule and the support of the context). Matches having confidence below `minconf` are discarded.
#
# The class `FSMRecommender` has the following initialization hyper-parameters:
# * `minsup`: the minimum support threshold. It is interpreted as relative count if in \[0-1\], otherwise as an absolute count. NOTE: Relative count required for training with SPFM (faster).
# * `minconf`: the minimum confidence threshold. Use to filter irrelevent recommendations.
# * `max_context`: the maximum number of items in the user profile (starting from the last) that will be used for lookup in the database of frequent sequences.
# * `min_context`: the minimum number of items in the user profile (starting from the last) that will be used for lookup in the database of frequent sequences.
# * `spmf_path`: path to SPMF jar file. If provided, SPFM library will be used for pattern extraction (algorithm: Prefix Span). Otherwise, use pymining, which can be significantly slower depending on the sequence database size.
# * `db_path`: path to the sequence database file

# %%
tmp_path = 'src/libs/RecSys_Course_2018/SequenceAware/tmp/'
spmf_path = 'src/libs/RecSys_Course_2018/SequenceAware/sars_tutorial_master/spmf/spmf.jar'

# then we instantiate and fit the recommender
recommender = FSMRecommender(URM_train,
                             train_sequential_df,
                             targetsListOrdered,
                             minsup=0.0005, # 0.002, 
                             minconf=1e-5, #0.1, 
                             min_context=1, 
                             max_context=10,
                             spmf_path=spmf_path,
                             tmp_path=tmp_path)

# %%
# calling fit() without arguments to use SPFM and the sequences stored in db_path
recommender.fit()
# calling fit() with an argument will use pymining.seqmining for pattern extraction (slower, MANDATORY ON BIDNDER) 
#recommender.fit(spmf=False)
# Out:
# 2019-01-03 02:49:25,399 - INFO - Using SPFM (Java) for Frequent Sequence Mining
# java -jar src/libs/RecSys_Course_2018/SequenceAware/sars_tutorial_master/spmf/spmf.jar run PrefixSpan src/libs/RecSys_Course_2018/SequenceAware/tmp/sequences.txt src/libs/RecSys_Course_2018/SequenceAware/tmp/tmp_output.txt 0.05%
# std out:  b'>/Users/archnnj/Development/recsys/recsys_polimi_challenge_2018/repo/src/libs/RecSys_Course_2018/SequenceAware/sars_tutorial_master/spmf/spmf.jar\n=============  PREFIXSPAN 0.99-2016 - STATISTICS =============\n Total time ~ 1098 ms\n Frequent sequences count : 99335\n Max memory (mb) : 260.3520278930664\n minsup = 3 sequences.\n Pattern count : 99335\n===================================================\n\n'
# std err:  None
# 2019-01-03 02:49:27,188 - INFO - 99335 frequent sequences found
# 2019-01-03 02:49:27,190 - INFO - Building the prefix tree
# 2019-01-03 02:55:45,431 - INFO - Training completed

# %%
#recommender.show_tree()

# %%
recommendations = recommender.recommend(targetsListOrdered) # tree is good, there must be sth wrong here
# Out:
# [12493, 17495, 13424, 7109, 14714, 15650, 15740, 159, 19243, 17920, 6620, 1063, 13808, 20023, 5893, 3483, 1775, 7660, 7478, 5649, 1461, 18190, 2494, 16890, 2204, 12393, 18418, 13640]
# 12493
# []

# %%
np.any(recommendations)
# Out:
# False

# %% [markdown]
# I didn't get any recom for any user even increasing params.. don't know :/ sth's missing

# %%
user_profile = recommender.train_data[recommender.train_data.user_id == targetsListOrdered[0]]['sequence'].values[0]
n = len(user_profile)
c = min(n, recommender.max_context)

# %%
user_profile[n - c:n]
# Out:
# [7478, 5649, 1461, 18190, 2494, 16890, 2204, 12393, 18418, 13640]

# %%
recommender.root_node
# Out:
# UUID('e2e7a3e9-e11d-44f6-b673-75f3f45402b0')

# %%
recommender.tree.
# Out:
# [Node(tag=root, identifier=e2e7a3e9-e11d-44f6-b673-75f3f45402b0, data=None),
#  Node(tag=1, identifier=726c2477-6e46-425d-90dd-8eaa95770177, data={'support': 6}),
#  Node(tag=6, identifier=38fdc77d-6b66-40c8-9ffb-e09980232c98, data={'support': 24}),
#  Node(tag=12295, identifier=ed0be943-133e-410a-b7a1-b270a4e24680, data={'support': 6}),
#  Node(tag=3212, identifier=f15405e3-267c-4bb9-95b9-9f0d9c4834d3, data={'support': 6}),
#  Node(tag=7323, identifier=72826026-9ca9-4b89-ba25-56323ca43ab0, data={'support': 7}),
#  Node(tag=13100, identifier=3c86b624-20d2-45b1-b920-ead8d9fa556b, data={'support': 5}),
#  Node(tag=10694, identifier=9e5b03ef-496c-4b15-84fb-fc21a1ef743f, data={'support': 5}),
#  Node(tag=15312, identifier=c721334c-996e-4948-b8ea-566daf2460f3, data={'support': 5}),
#  Node(tag=14679, identifier=6e8a00f5-bf02-40f0-8b19-9095634bb1ae, data={'support': 5}),
#  Node(tag=9060, identifier=bb6aec1a-a903-42fd-b7f8-351b5a74349f, data={'support': 8}),
#  Node(tag=9961, identifier=c4b0e063-f61b-4f3d-9b29-d2f071974fe1, data={'support': 5}),
#  Node(tag=6010, identifier=f4d84e54-9f69-4d8c-8a82-ff54dc95f946, data={'support': 5}),
#  Node(tag=15, identifier=ce7f5d4e-1c84-4553-8b4e-f8ea7bae8e43, data={'support': 11}),
#  Node(tag=21, identifier=bb530c44-0ecf-4d20-8032-ad98e52fcc27, data={'support': 6}),
#  Node(tag=23, identifier=38484bb7-e2c5-4c0e-8f99-8d8d09c9dbf7, data={'support': 9}),
#  Node(tag=24, identifier=80dcd652-fe4a-4518-ab20-0d29428e6d02, data={'support': 11}),
#  Node(tag=26, identifier=15bae047-99a4-4335-9851-faaf02bd4970, data={'support': 13}),
#  Node(tag=27, identifier=a71651aa-2bef-42e5-9212-77d99c2af045, data={'support': 10}),
#  Node(tag=28, identifier=708fb37f-cc10-42ae-85c8-b721bf7d6f91, data={'support': 17}),
#  Node(tag=2144, identifier=a6e40729-7e20-417e-a3cd-1591ff47932b, data={'support': 5}),
#  Node(tag=32, identifier=19581274-a410-4aa6-8456-ad65ad92fdba, data={'support': 9}),
#  Node(tag=33, identifier=4a6c5b2a-3758-42a8-94ce-08bfa8e17122, data={'support': 8}),
#  Node(tag=37, identifier=36108e12-04d0-43da-80ea-f0ba5bd097f0, data={'support': 18}),
#  Node(tag=38, identifier=05643f03-f663-4324-adb0-48b8f0008f9a, data={'support': 8}),
#  Node(tag=42, identifier=c033d1d9-5239-41b7-9a05-e6181df9c8fe, data={'support': 6}),
#  Node(tag=51, identifier=b24889df-6442-40d9-b181-786111773044, data={'support': 6}),
#  Node(tag=55, identifier=2a76e167-41d6-4d16-bb4f-f95171c26f09, data={'support': 6}),
#  Node(tag=56, identifier=a54fff28-2a24-40b7-9cba-e4cfbf18e3dd, data={'support': 26}),
#  Node(tag=6776, identifier=85e2f501-5861-4d57-999d-34c3b52a8459, data={'support': 5}),
#  Node(tag=16521, identifier=688d94ed-ecc7-4ce0-9fe1-1c2cd34498d1, data={'support': 5}),
#  Node(tag=60, identifier=dcee542c-649b-41e8-9d24-44fbcb6b510d, data={'support': 5}),
#  Node(tag=65, identifier=c1115cd9-f384-4aa3-8e5e-1371b8966b0a, data={'support': 12}),
#  Node(tag=69, identifier=886e4ee6-b448-4934-8bd5-2edee5fc7fad, data={'support': 5}),
#  Node(tag=73, identifier=1a62b9d5-8b05-4628-b544-4fa120c4ee0b, data={'support': 13}),
#  Node(tag=75, identifier=3d5f2cb6-eff9-4e65-9b6f-67003cdb01ad, data={'support': 14}),
#  Node(tag=80, identifier=cd7e43d4-a05b-499b-9cd7-1ad2feaa7a80, data={'support': 56}),
#  Node(tag=3431, identifier=7c4722b9-084b-4749-b07d-4f954925bc7e, data={'support': 5}),
#  Node(tag=541, identifier=491ee7fa-6cb9-42d6-8f60-576d4764c708, data={'support': 5}),
#  Node(tag=2674, identifier=6098b0f5-98a2-4280-a78c-9cb17c8d00f1, data={'support': 9}),
#  Node(tag=6937, identifier=be1e5549-2fce-42db-a297-ac72167945dc, data={'support': 7}),
#  Node(tag=1895, identifier=eb86e718-e2f9-427f-8d56-7a45f50dccdd, data={'support': 5}),
#  Node(tag=2997, identifier=28f6d833-b1f0-4213-96dd-0799a4712d41, data={'support': 8}),
#  Node(tag=88, identifier=0074f55d-0fde-43f1-add7-27715b73a4f1, data={'support': 5}),
#  Node(tag=92, identifier=f73b8c67-80ca-42e9-bd4f-c377b7389e63, data={'support': 8}),
#  Node(tag=103, identifier=a5f593f8-3b2b-42dc-8a95-c5c8767dda5c, data={'support': 10}),
#  Node(tag=108, identifier=a56bcd54-f989-4884-a815-f21d258ff24b, data={'support': 6}),
#  Node(tag=117, identifier=1904a228-3286-479a-88aa-a15c51a054dc, data={'support': 13}),
#  Node(tag=120, identifier=28dc0ba6-870f-4078-9d20-157ea608a252, data={'support': 6}),
#  Node(tag=123, identifier=1e8f7dc7-0154-4560-9dbf-61b38a3fa220, data={'support': 19}),
#  Node(tag=125, identifier=0b9ebff8-35d8-4e51-b2ee-b466c3d391de, data={'support': 11}),
#  Node(tag=149, identifier=d6cef3fd-5f58-4da9-befc-7bf6fa192e19, data={'support': 18}),
#  Node(tag=10019, identifier=b83a9d6e-45dc-4d2b-8f3d-88d4a493125f, data={'support': 7}),
#  Node(tag=159, identifier=bb243970-706a-4632-8b2f-cb4ad6b171f0, data={'support': 8}),
#  Node(tag=163, identifier=f8fe3ea5-6713-4134-9045-05fc2fe7de7e, data={'support': 6}),
#  Node(tag=176, identifier=b8e02da8-3e93-4f8d-9142-214f95270f4e, data={'support': 6}),
#  Node(tag=178, identifier=6936e935-608f-40c9-9f88-8a018f945ce9, data={'support': 13}),
#  Node(tag=181, identifier=a4d127d0-2f51-4a40-a6b5-044d0b2d3a56, data={'support': 12}),
#  Node(tag=193, identifier=2499e416-3f11-4d70-969a-fdab217fceb5, data={'support': 5}),
#  Node(tag=195, identifier=eb5daeb0-1038-411d-bf55-1ff743aa1a08, data={'support': 5}),
#  Node(tag=197, identifier=8bca4427-b37d-486f-9564-ef160cb31191, data={'support': 7}),
#  Node(tag=198, identifier=05cc09cb-dc70-4a09-913a-5b66e17b194f, data={'support': 5}),
#  Node(tag=204, identifier=f2bd3d22-13d3-4de5-a88f-b3512dc02626, data={'support': 5}),
#  Node(tag=207, identifier=69d92116-1a6b-4044-9e97-6911bc633b1c, data={'support': 8}),
#  Node(tag=209, identifier=05adece6-46bd-4e65-ac3d-5dd439dc2dab, data={'support': 9}),
#  Node(tag=215, identifier=0a28a436-05ec-4d48-9a36-19ccaf52cd79, data={'support': 11}),
#  Node(tag=216, identifier=049bffa2-ffc4-44eb-8fcd-8c4e4b07a496, data={'support': 21}),
#  Node(tag=222, identifier=10426346-0228-4e7b-a0f4-73d32e281156, data={'support': 12}),
#  Node(tag=11013, identifier=ed522e44-969f-4232-ac21-5002b3c7fe3d, data={'support': 6}),
#  Node(tag=228, identifier=cbd1d3c5-a777-4f22-a57e-858749e1c98c, data={'support': 5}),
#  Node(tag=229, identifier=1e61bc14-dbec-4e50-bac7-c0fb2a76e40f, data={'support': 25}),
#  Node(tag=235, identifier=30071d0f-875b-4f2f-8f4b-337627a8732b, data={'support': 6}),
#  Node(tag=247, identifier=2bb8a544-f3f8-4808-aa62-dcd4932c5ab3, data={'support': 6}),
#  Node(tag=250, identifier=73b6ee5f-fdc9-454d-8a87-309860ae58e8, data={'support': 5}),
#  Node(tag=260, identifier=8df5dc39-98eb-49fa-aaaa-32a1f2f56bb5, data={'support': 6}),
#  Node(tag=263, identifier=39820584-6f9e-447c-ad57-8cb529585f63, data={'support': 6}),
#  Node(tag=268, identifier=121f779d-1f67-42ef-adaa-85a2cbfe6b17, data={'support': 15}),
#  Node(tag=277, identifier=61a1d50b-1e43-492a-859e-425d28a82e54, data={'support': 30}),
#  Node(tag=18404, identifier=2fc80e2a-13ee-4ec6-9103-82cdd65ee747, data={'support': 5}),
#  Node(tag=280, identifier=e49b7ac0-1ec7-4c68-8aea-6b7df667fb5c, data={'support': 36}),
#  Node(tag=281, identifier=f604bdd5-6c5a-45a0-aea1-4964880d83cf, data={'support': 14}),
#  Node(tag=285, identifier=b1d85ca8-aa38-4a96-9209-760ec97c890c, data={'support': 9}),
#  Node(tag=288, identifier=9239bc2f-bb5b-4433-9fbb-03ad9a5f4d24, data={'support': 6}),
#  Node(tag=296, identifier=4afa5a2c-a41f-439e-99d0-1dd070e18596, data={'support': 8}),
#  Node(tag=299, identifier=4d3441bd-fcfe-48ec-9ff7-bf5c33581bbf, data={'support': 8}),
#  Node(tag=302, identifier=7768812a-466e-45ef-8cf5-d996772c526c, data={'support': 9}),
#  Node(tag=306, identifier=bb432b62-2386-47a6-9ce4-efc91e85ca62, data={'support': 7}),
#  Node(tag=308, identifier=f6ca5d75-b53c-447d-a047-50d3b7c18c4f, data={'support': 31}),
#  Node(tag=315, identifier=2340b470-8532-4220-a2b3-6e63fcdc725f, data={'support': 17}),
#  Node(tag=316, identifier=fe56dabc-5fe9-4a3c-8d1a-1753f0ccb18d, data={'support': 25}),
#  Node(tag=317, identifier=2a63a8c2-47f0-4c88-a787-970ebaf021a9, data={'support': 10}),
#  Node(tag=318, identifier=0d9cc758-e313-478b-b1bf-659482c4a8cb, data={'support': 11}),
#  Node(tag=323, identifier=2da10261-23bc-4009-ad85-0b4c3da60e37, data={'support': 7}),
#  Node(tag=333, identifier=d5c6954f-dd67-4d61-81b1-9b393262fff0, data={'support': 14}),
#  Node(tag=339, identifier=67d34f71-3216-454d-8c57-78c1c5034558, data={'support': 8}),
#  Node(tag=344, identifier=af8a0ad8-5bc7-4fca-95e0-bb5b0b6a11cb, data={'support': 19}),
#  Node(tag=350, identifier=cb2ce023-5250-4de2-8801-3adb08eb74d1, data={'support': 7}),
#  Node(tag=355, identifier=41422146-05f0-47df-b84f-ccfb4e3c5151, data={'support': 6}),
#  Node(tag=358, identifier=f99b3c9e-ebf0-42c8-b72b-7852fe5dea3f, data={'support': 21}),
#  Node(tag=359, identifier=f10367a8-186b-4af6-b109-24a63b73795e, data={'support': 16}),
#  Node(tag=360, identifier=e1d7e08e-14ab-4493-9602-ae21c8aa5688, data={'support': 59}),
#  Node(tag=10264, identifier=51f56dc3-ca35-4e91-8297-8e4d68f32e7b, data={'support': 10}),
#  Node(tag=14395, identifier=32166ed2-5c06-49e8-af9c-69aad423f744, data={'support': 9}),
#  Node(tag=11366, identifier=fbddb009-6814-41a7-96f7-9aa654c85944, data={'support': 5}),
#  Node(tag=6253, identifier=5784cf7e-c7a8-4ecd-909a-cb6d4e92b14a, data={'support': 10}),
#  Node(tag=17597, identifier=35254662-418f-423d-8bb7-82aa5d364bbe, data={'support': 5}),
#  Node(tag=18637, identifier=b4ba5d74-ff43-4fb4-a85c-8cad00d0ea3d, data={'support': 5}),
#  Node(tag=15570, identifier=054eba1c-b0fb-4e90-a566-f5d7fd731e7d, data={'support': 5}),
#  Node(tag=18649, identifier=86f90eb2-c9b7-46a0-ae2c-ff1049d0b382, data={'support': 5}),
#  Node(tag=15578, identifier=33409388-f4b1-4162-b316-7cb521c0ef2a, data={'support': 6}),
#  Node(tag=14591, identifier=b6187fdb-abbd-4a25-ac52-cf60bcdcf4dc, data={'support': 8}),
#  Node(tag=10496, identifier=cd7444d1-953a-4421-8a96-b4dc25c3c362, data={'support': 6}),
#  Node(tag=12563, identifier=f3bb8ff2-23d0-4b69-b33c-ed7b93382ec6, data={'support': 5}),
#  Node(tag=18728, identifier=358ef964-ee35-4a4c-a38b-d7ac6203d131, data={'support': 9}),
#  Node(tag=7619, identifier=d7f955d6-51f6-4ced-b42d-da2de42b37b0, data={'support': 5}),
#  Node(tag=13782, identifier=1c6d5ccb-808a-4471-8cc1-272694f36153, data={'support': 10}),
#  Node(tag=14859, identifier=6721c548-52c1-40d6-80b1-9e57440678ed, data={'support': 5}),
#  Node(tag=541, identifier=c1501096-6e78-4ea1-acaa-374a39caa97d, data={'support': 6}),
#  Node(tag=11896, identifier=adb3a921-b66f-46e4-a1f5-e1ce00fac124, data={'support': 5}),
#  Node(tag=13980, identifier=080d6bdc-7642-4085-8418-79f3376d0d84, data={'support': 8}),
#  Node(tag=4795, identifier=5b383734-04cf-4523-b30a-ce8c727b831c, data={'support': 6}),
#  Node(tag=17096, identifier=055f23e2-7a07-4dec-aae9-04231f492723, data={'support': 6}),
#  Node(tag=1746, identifier=2c39111f-d7cb-417e-a59f-e9944a1c828e, data={'support': 5}),
#  Node(tag=8956, identifier=427f1257-b88b-433b-8e8d-2e7420c99d1b, data={'support': 14}),
#  Node(tag=14395, identifier=45601062-f4cd-4b1a-aeb4-bba0fb280712, data={'support': 5}),
#  Node(tag=13101, identifier=7589a96c-4f2a-4dda-9cf2-73adfd197038, data={'support': 7}),
#  Node(tag=3885, identifier=02a1fec4-9390-4eb3-a283-ea43b7acb12b, data={'support': 5}),
#  Node(tag=17239, identifier=86a8865c-5cd0-4c46-87c8-8ae37d79470b, data={'support': 8}),
#  Node(tag=13237, identifier=7054a937-fd86-4e9a-b006-5871f2c8f276, data={'support': 11}),
#  Node(tag=10264, identifier=2277fff1-5fd9-447b-98f3-c2f9f225160b, data={'support': 5}),
#  Node(tag=11206, identifier=14d5a892-998b-4b62-82ea-96e00dc9d110, data={'support': 5}),
#  Node(tag=18381, identifier=29d5f50b-6ec3-400a-898c-48744a785024, data={'support': 11}),
#  Node(tag=18389, identifier=06a0c673-1714-4637-8508-b98e8e94a7a0, data={'support': 5}),
#  Node(tag=19422, identifier=d56c8974-962d-4877-b690-2485b1fbc004, data={'support': 5}),
#  Node(tag=361, identifier=f2733471-0825-4e7a-b08b-bc301696ba00, data={'support': 5}),
#  Node(tag=362, identifier=5a88e473-f630-4277-9107-b28f1eb8a490, data={'support': 22}),
#  Node(tag=19362, identifier=59f990f5-f158-49bd-9c28-b318d1aa6744, data={'support': 6}),
#  Node(tag=368, identifier=8a5d370b-4240-4166-bfb2-73be555bafcb, data={'support': 31}),
#  Node(tag=371, identifier=ea8bbf8d-968e-4418-8d18-90f11d1c2f81, data={'support': 28}),
#  Node(tag=372, identifier=35e0e82f-f362-43dc-b6c7-40706929b62a, data={'support': 6}),
#  Node(tag=378, identifier=fcf406ad-75d6-44ce-821b-131c225161aa, data={'support': 8}),
#  Node(tag=381, identifier=754f95db-0fc9-4aa9-b821-ee26339be69b, data={'support': 13}),
#  Node(tag=387, identifier=a4701116-e34f-43cb-9649-4994ffbd2adb, data={'support': 29}),
#  Node(tag=14904, identifier=e66c3007-8130-4bc5-8b4e-9382c5a27897, data={'support': 5}),
#  Node(tag=9211, identifier=d1e1b424-6c9e-4108-bcc4-0628e9f12a42, data={'support': 7}),
#  Node(tag=394, identifier=f4915fbe-1180-47b5-9f82-2c42d139231b, data={'support': 42}),
#  Node(tag=19466, identifier=18939729-f85d-426c-8998-b651200ca7f5, data={'support': 6}),
#  Node(tag=9804, identifier=5c2a09fb-c8ad-4b8c-9547-ed75a1b10ecb, data={'support': 6}),
#  Node(tag=10339, identifier=9acd174d-2055-4042-a16f-b85f013bd7d9, data={'support': 5}),
#  Node(tag=2665, identifier=b1dc6aa5-4c55-4bd2-88a7-84d9cf31d538, data={'support': 5}),
#  Node(tag=16583, identifier=b1c58257-a668-4d29-93e9-215dbc450c74, data={'support': 5}),
#  Node(tag=9002, identifier=c5b5c717-f6cd-48fe-840f-2d87bf49d411, data={'support': 5}),
#  Node(tag=13622, identifier=7e243b5e-b6b5-471d-8e66-f1bc3eef8f14, data={'support': 6}),
#  Node(tag=18743, identifier=464a5869-6742-4c92-9b3d-2bde75689266, data={'support': 5}),
#  Node(tag=395, identifier=1cc968ee-2be4-4718-b5a0-6d20a1aadf34, data={'support': 7}),
#  Node(tag=396, identifier=6785afea-7c86-420a-8211-0b4d72f93f73, data={'support': 14}),
#  Node(tag=397, identifier=0d54c0e8-cdc7-4fd0-b2e2-f84d20e2b9be, data={'support': 15}),
#  Node(tag=401, identifier=c87a4ec2-a977-4342-95b4-37c77da5931d, data={'support': 7}),
#  Node(tag=402, identifier=334af990-c2ab-43ae-89c7-4ac5768a06d9, data={'support': 8}),
#  Node(tag=405, identifier=8a3d00aa-cf51-41b5-a819-30741d50cce1, data={'support': 48}),
#  Node(tag=4148, identifier=cb9cb788-a17b-4b2d-b00c-7e40d9cd9e50, data={'support': 6}),
#  Node(tag=4743, identifier=4efec2ab-4907-4ccc-b524-b5f40d32f700, data={'support': 10}),
#  Node(tag=16521, identifier=a361bff5-c57d-4004-a23d-1487984b70c3, data={'support': 5}),
#  Node(tag=4800, identifier=f9b36291-5d87-4dcc-b4e2-2eee50e7b847, data={'support': 5}),
#  Node(tag=9963, identifier=04017638-c2a2-4701-a230-064a24dc81c2, data={'support': 5}),
#  Node(tag=4916, identifier=542b0e9f-ba33-46b4-a91a-2187e764b841, data={'support': 5}),
#  Node(tag=20329, identifier=617eaddb-eea2-4de4-92ec-d7853d02e47a, data={'support': 5}),
#  Node(tag=8045, identifier=75e3d57d-9cb4-4072-941d-c9a5df514a3e, data={'support': 5}),
#  Node(tag=8138, identifier=adbbfb7e-aa25-4119-9de5-74e338bb49f1, data={'support': 5}),
#  Node(tag=8169, identifier=e43ca068-15c1-455a-aade-81daf310a82b, data={'support': 6}),
#  Node(tag=411, identifier=b7cf901d-2d8a-4a34-9352-4032a63031f9, data={'support': 62}),
#  Node(tag=20515, identifier=b76063c3-5fa8-453a-a5b6-ba9e7ddf4556, data={'support': 5}),
#  Node(tag=16502, identifier=33fa702a-933c-4832-b810-17a55ae20c8e, data={'support': 7}),
#  Node(tag=17584, identifier=4790ac71-bb1d-4bb6-a116-c4a46107c36a, data={'support': 7}),
#  Node(tag=8491, identifier=3eb51649-12ad-4d1e-8052-74efe8a139a5, data={'support': 6}),
#  Node(tag=4482, identifier=10a9dec1-4c00-4015-bd43-8f647c5b3141, data={'support': 7}),
#  Node(tag=15771, identifier=5142c6d8-31c4-42e3-97ce-6e21918ccbbd, data={'support': 8}),
#  Node(tag=2497, identifier=08a80b17-ddb8-4a18-a1d7-01ff0999cc9d, data={'support': 10}),
#  Node(tag=5572, identifier=19f56cf4-e10c-4567-9ee9-eb69b5b84751, data={'support': 7}),
#  Node(tag=4600, identifier=c4a542e1-bc07-4b4b-81fe-8a0575ca7037, data={'support': 6}),
#  Node(tag=17984, identifier=18eddc5f-f5e9-4eab-931d-a04e218dd0de, data={'support': 5}),
#  Node(tag=10848, identifier=577e3533-bf73-44b8-9ac1-3899c8f52941, data={'support': 10}),
#  Node(tag=14008, identifier=e3f71303-a4f1-4024-a6fd-b6f90aa10807, data={'support': 12}),
#  Node(tag=20172, identifier=6bbf8864-705d-4558-9684-dbb5e5b6bfb5, data={'support': 10}),
#  Node(tag=10848, identifier=f92e29ac-00da-40a8-9efe-35e974c3e896, data={'support': 5}),
#  Node(tag=12013, identifier=87694007-34c4-4e7c-9a6e-900824e54d94, data={'support': 5}),
#  Node(tag=20263, identifier=227b1985-b9b6-4e1e-93d7-05660d309058, data={'support': 5}),
#  Node(tag=2919, identifier=6b24905f-becf-4db2-8f3d-75e98a324173, data={'support': 6}),
#  Node(tag=3976, identifier=97462ce8-1744-4d74-8446-17bde37ec880, data={'support': 6}),
#  Node(tag=412, identifier=a27f90a9-8308-46ef-ab2f-ca2365d54d24, data={'support': 11}),
#  Node(tag=414, identifier=df389f88-bbbd-425e-8b9a-0044645a95a7, data={'support': 19}),
#  Node(tag=425, identifier=90dfb6fe-5bc2-4e05-b81e-dd323e73e39f, data={'support': 7}),
#  Node(tag=436, identifier=4bd18b8d-a702-40b0-b09a-6ee313bf90f0, data={'support': 26}),
#  Node(tag=438, identifier=55e6be6e-7011-4e13-ae25-8d7ba941967b, data={'support': 19}),
#  Node(tag=11173, identifier=5e54d3ab-e29b-4d9d-ae30-9f2283c72be8, data={'support': 5}),
#  Node(tag=443, identifier=bcdb52b7-c721-4683-8e3e-6aa59fbdfc2c, data={'support': 5}),
#  Node(tag=444, identifier=2622dbe6-8f4c-4624-af7f-350948ebbe49, data={'support': 13}),
#  Node(tag=453, identifier=d4f3b0f7-36a2-49be-8cbf-f256e7ff482a, data={'support': 8}),
#  Node(tag=456, identifier=242d7dc7-bed7-48e1-bc2a-f7ef2f920d7a, data={'support': 27}),
#  Node(tag=13592, identifier=410f7fbc-5a72-4ad6-aa14-ec6a52e689c5, data={'support': 5}),
#  Node(tag=457, identifier=52600ea6-75e5-4e74-948c-e5a12ad591d0, data={'support': 18}),
#  Node(tag=459, identifier=cd2d145a-c987-446e-9495-7a31e143b945, data={'support': 10}),
#  Node(tag=460, identifier=4860b013-3802-45c5-94a3-1321e704dba7, data={'support': 5}),
#  Node(tag=463, identifier=b549862e-65a7-495c-8676-7e7088e03d4f, data={'support': 25}),
#  Node(tag=467, identifier=1581d8a8-7bb0-4032-a970-ea6e1ff9953d, data={'support': 14}),
#  Node(tag=468, identifier=d5a863df-7b84-431f-8a89-40ed1dca68bf, data={'support': 10}),
#  Node(tag=475, identifier=dcc03773-38b6-4855-b4b2-f6fabd7aef19, data={'support': 5}),
#  Node(tag=477, identifier=d714ff0c-8e12-443e-926e-d812670489ce, data={'support': 6}),
#  Node(tag=482, identifier=f5c4d89d-caf9-4cc5-a33b-564d6e0723c2, data={'support': 6}),
#  Node(tag=484, identifier=913765fa-36a7-4d15-abb5-7b42fa04e7ae, data={'support': 5}),
#  Node(tag=490, identifier=685fa039-2bea-49f8-9e89-b25cb4519e9d, data={'support': 8}),
#  Node(tag=495, identifier=873485f5-1e63-467a-8e92-2ee4f84c0f98, data={'support': 6}),
#  Node(tag=505, identifier=8031c80c-4689-42f2-aef7-4e4473753272, data={'support': 6}),
#  Node(tag=507, identifier=158ac704-f22d-41be-a8f3-75be090c6b5a, data={'support': 7}),
#  Node(tag=508, identifier=f9e9b80b-b3cf-402f-9e8f-176541b7c85f, data={'support': 44}),
#  Node(tag=3698, identifier=f4c4e29b-b6ad-4491-b32c-d6eb78b95370, data={'support': 5}),
#  Node(tag=9346, identifier=9bf65628-5978-4c7f-a5c8-e9b12274bd86, data={'support': 5}),
#  Node(tag=16579, identifier=4cf83dcd-154b-4281-b84f-00a02cb0feb8, data={'support': 5}),
#  Node(tag=4301, identifier=98bcca92-9330-4369-a787-9f48bc6c3640, data={'support': 6}),
#  Node(tag=10481, identifier=bdfb14d6-0dbb-4bd7-add8-ed704ef5799f, data={'support': 15}),
#  Node(tag=16673, identifier=18722532-e31c-42a9-ada0-a34f360589c9, data={'support': 7}),
#  Node(tag=16673, identifier=d9aceb66-df46-4c62-ba58-8b71315e3a1e, data={'support': 11}),
#  Node(tag=5947, identifier=a3c4dbb6-8ddc-466a-8a3b-c97f1e325931, data={'support': 5}),
#  Node(tag=7081, identifier=1cd590e0-193e-40a6-98c9-0ea1de748df1, data={'support': 5}),
#  Node(tag=2989, identifier=cfe2e13b-ad1c-4790-babd-9450992e89e7, data={'support': 5}),
#  Node(tag=18361, identifier=a523d158-6b0f-4f8b-b4e2-3d86f38c93ef, data={'support': 5}),
#  Node(tag=8640, identifier=4c8e0f02-f07f-43ab-af77-50f5cb9ba358, data={'support': 7}),
#  Node(tag=11715, identifier=bd282283-b186-4aec-a0fb-105c04eacbe9, data={'support': 5}),
#  Node(tag=4089, identifier=8c772a67-f85b-40cc-b3cd-d9f867fde142, data={'support': 7}),
#  Node(tag=509, identifier=d059a8fa-a098-41dd-b5e0-92bb787b8ce3, data={'support': 5}),
#  Node(tag=512, identifier=caa2dfe4-4e93-4191-b38e-622177650d19, data={'support': 13}),
#  Node(tag=514, identifier=d4b2ea6a-fab1-480d-9372-de0a0bd2d77f, data={'support': 9}),
#  Node(tag=515, identifier=b5204ef9-3477-4727-96c1-47dbc35a703b, data={'support': 5}),
#  Node(tag=519, identifier=17c3947a-d141-419c-a246-09c5e39f15e2, data={'support': 20}),
#  Node(tag=520, identifier=53b8da22-30fd-4e4e-8606-d6be6a4439e8, data={'support': 40}),
#  Node(tag=16404, identifier=8ac1ac99-4a6e-4cfc-8a77-ce43a0fbe7e5, data={'support': 8}),
#  Node(tag=15471, identifier=96cd50a9-9bb1-40d7-b3de-08effe7c4283, data={'support': 5}),
#  Node(tag=1710, identifier=0ad83695-16c4-41a7-a4b1-b2819cd46c10, data={'support': 5}),
#  Node(tag=523, identifier=7163cdc0-6e98-4f9c-89a7-d94a8679063f, data={'support': 17}),
#  Node(tag=8885, identifier=fbef4a91-58e3-4af7-8144-b1696b8f6206, data={'support': 6}),
#  Node(tag=535, identifier=3f6c4df3-b18e-4037-b899-fea7a2e1191b, data={'support': 7}),
#  Node(tag=541, identifier=d9d130ff-26d7-4b35-bc4d-dd2cc37623db, data={'support': 96}),
#  Node(tag=10250, identifier=575c200b-1cdd-4191-a9b7-2261f6d0970d, data={'support': 8}),
#  Node(tag=17459, identifier=81521071-cdb3-4320-8c3b-283ad8d56d13, data={'support': 5}),
#  Node(tag=14395, identifier=38f88c98-a6d5-4dcd-84a7-c83f5a7f3ed9, data={'support': 7}),
#  Node(tag=80, identifier=98ebfe59-2003-4b48-b4b5-3d54d75130e7, data={'support': 6}),
#  Node(tag=6253, identifier=58291f70-3e53-4f36-b42b-325c209baf53, data={'support': 9}),
#  Node(tag=11373, identifier=b0ec6999-794c-4129-9a33-1eeba917ecff, data={'support': 14}),
#  Node(tag=12425, identifier=118f0866-7505-4f28-932f-8f945290d793, data={'support': 11}),
#  Node(tag=18649, identifier=f9ce0745-2e04-4f03-9ded-9d833362892b, data={'support': 7}),
#  Node(tag=15578, identifier=603b6f37-3634-495c-bb12-968d16616492, data={'support': 9}),
#  Node(tag=17652, identifier=f35c9ca0-d540-4698-bfe0-3e316abb97ff, data={'support': 5}),
#  Node(tag=6411, identifier=b1366cf0-c0f4-4510-99d7-5dfd5b68f5ba, data={'support': 12}),
#  Node(tag=18728, identifier=8d021027-303a-4c81-9781-8e9db4723f5b, data={'support': 6}),
#  Node(tag=2367, identifier=f1266fb0-5d08-41d1-bea3-55f2b3037a5f, data={'support': 5}),
#  Node(tag=3431, identifier=a1ca4f4b-a505-4bea-9122-284198b6eaa9, data={'support': 6}),
#  Node(tag=2412, identifier=a78cd3b8-2d42-406e-8332-0018ec14e647, data={'support': 6}),
#  Node(tag=14758, identifier=867b9464-4728-4fe8-98c4-42f61ffa6700, data={'support': 7}),
#  Node(tag=11699, identifier=eef812cd-9947-49b2-a5b3-89732b09eb33, data={'support': 9}),
#  Node(tag=16862, identifier=c953888e-fa01-48ca-a26e-bc9554aafab4, data={'support': 5}),
#  Node(tag=9705, identifier=47b701f7-8459-4ceb-b8e1-3e7e58622cd6, data={'support': 7}),
#  Node(tag=8681, identifier=4b156cc7-ca37-449a-8f4f-b50df33f0744, data={'support': 5}),
#  Node(tag=13833, identifier=92546702-d798-4279-bade-3af89ce6ef29, data={'support': 5}),
#  Node(tag=14885, identifier=4476fb94-4426-4e86-8974-bec1cc81f48c, data={'support': 6}),
#  Node(tag=10848, identifier=c04233d8-145b-49ac-8940-6a4a867f57b5, data={'support': 7}),
#  Node(tag=2674, identifier=160b22cc-48c3-4455-af7a-bc2c2eb03352, data={'support': 12}),
#  Node(tag=648, identifier=ee66ee11-39aa-4038-94a5-a884f1eff5a3, data={'support': 5}),
#  Node(tag=2705, identifier=ec9548c2-2032-4442-8562-f65f7962aacf, data={'support': 6}),
#  Node(tag=13980, identifier=6b10448c-da60-472e-96c3-0753d59e0c86, data={'support': 6}),
#  Node(tag=20134, identifier=228c7544-9ae6-4d4e-9e4b-588db5e28a2c, data={'support': 7}),
#  Node(tag=9941, identifier=2511d71f-4f75-4a7f-94ab-2706764a5233, data={'support': 5}),
#  Node(tag=8956, identifier=0dd26f68-1ce3-4c28-9f05-45b5fce73a11, data={'support': 7}),
#  Node(tag=13101, identifier=f473ba69-db00-4ffe-b510-9d87f679426a, data={'support': 7}),
#  Node(tag=11070, identifier=2abb0caa-307b-4d80-8250-9e3126c73502, data={'support': 10}),
#  Node(tag=8018, identifier=1679db66-d415-4f33-a836-c58da95a7268, data={'support': 7}),
#  Node(tag=13139, identifier=70e0c6b2-196a-4fbe-8c8b-ddd418bd64a1, data={'support': 7}),
#  Node(tag=17239, identifier=3fbaf73e-0c2b-45da-9022-5ff0fee42a54, data={'support': 7}),
#  Node(tag=6253, identifier=72ce782b-d9ba-4372-b8b4-92ed65186c59, data={'support': 5}),
#  Node(tag=2912, identifier=f6d2d963-0b5d-4fd1-8e85-3dd9a1d8db39, data={'support': 5}),
#  Node(tag=7009, identifier=c4766ea8-fc04-410f-bbaa-d62d235da6aa, data={'support': 5}),
#  Node(tag=11107, identifier=f7a01baf-df0d-4fda-b645-1a497d831a5b, data={'support': 8}),
#  Node(tag=2930, identifier=9b1162a1-08db-4c9c-a4bc-c1a8df05dfba, data={'support': 5}),
#  Node(tag=2997, identifier=a31014d9-9c9d-4cfc-a521-ba90b5ee5139, data={'support': 6}),
#  Node(tag=13237, identifier=51aab605-0963-4a27-82c7-4bfbc4d0398b, data={'support': 8}),
#  Node(tag=11206, identifier=fc6525ee-ad1c-4ff3-a8ba-b01ca481b377, data={'support': 5}),
#  Node(tag=19422, identifier=04421fe0-fa1d-4a32-b6d3-56b3e820f12d, data={'support': 5}),
#  Node(tag=12261, identifier=637e4d5a-4bd5-4442-869d-366d802ef618, data={'support': 5}),
#  Node(tag=12262, identifier=6bdbb6f4-e94e-4478-a670-95b897f4e62b, data={'support': 7}),
#  Node(tag=548, identifier=a30e5299-3985-4423-845d-a8287fbb8409, data={'support': 17}),
#  Node(tag=550, identifier=acb3a4bc-17f7-4e47-9b62-8d474a151013, data={'support': 24}),
#  Node(tag=17157, identifier=087ff01f-f282-40f7-9bfc-b07b3aa21bd8, data={'support': 6}),
#  Node(tag=551, identifier=de0c3a89-1da5-4233-936f-5b837f4089be, data={'support': 5}),
#  Node(tag=553, identifier=f3592cd2-6f2b-4e8c-a42c-82bddc2807fd, data={'support': 12}),
#  Node(tag=559, identifier=b23a5d51-dcf0-4a37-b41d-d34cefd20dcd, data={'support': 9}),
#  Node(tag=563, identifier=cbcbcb73-960e-4a91-8fa9-e59c4c9ac336, data={'support': 13}),
#  Node(tag=573, identifier=002f4c96-9b97-4fdb-a6cc-4cdc8d44160a, data={'support': 53}),
#  Node(tag=6253, identifier=c4605c40-dadc-4a4f-92dc-4a8e7a081c58, data={'support': 9}),
#  Node(tag=18649, identifier=6e701e66-9964-4f66-9f2f-bddfc8f588f4, data={'support': 5}),
#  Node(tag=15670, identifier=021bb345-299c-4997-8338-f2c7fa5f191a, data={'support': 6}),
#  Node(tag=2412, identifier=8cbfbc2f-d4b5-40c7-a226-e2ea9c715c26, data={'support': 5}),
#  Node(tag=9624, identifier=83ceb3fe-5d23-404e-af09-a9907f25e989, data={'support': 6}),
#  Node(tag=8681, identifier=004e726b-52b6-457c-97cf-8be6f56a9bb3, data={'support': 6}),
#  Node(tag=9712, identifier=14548fa6-d7de-4cfa-821b-b7c111f20017, data={'support': 7}),
#  Node(tag=2674, identifier=2347882c-2b97-479b-b676-21f17ff6fec6, data={'support': 5}),
#  Node(tag=13980, identifier=9ae4af4a-9c29-4e6c-8fc7-74458e6ee1da, data={'support': 5}),
#  Node(tag=4795, identifier=ec7e3561-2f40-4a2e-9917-1483ea0a2aee, data={'support': 6}),
#  Node(tag=1746, identifier=7c4f3d65-1778-4a9a-8846-04c0d209c31d, data={'support': 14}),
#  Node(tag=8953, identifier=d24bfa02-ba31-411c-abca-94658bc980d6, data={'support': 5}),
#  Node(tag=778, identifier=5d91ce32-f1d0-457c-83c5-3dc5aaebbc1c, data={'support': 9}),
#  Node(tag=5903, identifier=f579fb6d-0420-4f42-a2e9-da700a06c6b6, data={'support': 10}),
#  Node(tag=13101, identifier=3362fb45-20a1-414e-8f2c-81ef9d1866fa, data={'support': 9}),
#  Node(tag=13139, identifier=84ae2182-b879-4036-8ab7-fd0500d6a8e9, data={'support': 5}),
#  Node(tag=17239, identifier=e6064a9d-edba-4bcc-98db-94825b2554ae, data={'support': 5}),
#  Node(tag=7009, identifier=a981cf52-a871-49b7-96cd-ccf4de05b696, data={'support': 5}),
#  Node(tag=7092, identifier=2722d38f-a33e-476a-9045-a1a1c092f128, data={'support': 5}),
#  Node(tag=18381, identifier=3b8fc74b-0c6a-4c03-9ff0-635ca30b0431, data={'support': 5}),
#  Node(tag=574, identifier=27f61746-09a0-47c8-90c1-17410c4d4071, data={'support': 5}),
#  Node(tag=575, identifier=f7b1b0c0-2021-4913-83ea-091ceaeb1fa5, data={'support': 5}),
#  Node(tag=579, identifier=0d111f78-da03-43a8-9b7b-96df7bd38192, data={'support': 35}),
#  Node(tag=20004, identifier=9033ebd9-f66d-447d-ba8f-9dd5ac635fc5, data={'support': 5}),
#  Node(tag=7224, identifier=8463817a-5d18-400b-83f1-dd067e76bea9, data={'support': 5}),
#  Node(tag=20163, identifier=b7fe973d-082d-49db-8ed2-fc44d9a4c222, data={'support': 5}),
#  Node(tag=16144, identifier=87fe870d-059c-4be2-9aac-f338c1f46756, data={'support': 6}),
#  Node(tag=6433, identifier=7073a940-fa99-4b21-8a7c-b6dbbb40cf96, data={'support': 6}),
#  Node(tag=13154, identifier=4432c49d-ad62-4c62-9d8d-4ad942e9677e, data={'support': 7}),
#  Node(tag=9120, identifier=ba12622e-2a34-42d3-a9c6-af834b58afe5, data={'support': 6}),
#  Node(tag=4089, identifier=e5e6d624-8795-4e02-870d-fd774f6f413d, data={'support': 7}),
#  Node(tag=508, identifier=30cd758a-67b4-4a15-9eac-567a63d09e54, data={'support': 6}),
#  Node(tag=586, identifier=bd117b1c-f6e6-4541-b1b0-8760d70a4f8e, data={'support': 10}),
#  Node(tag=593, identifier=a2fcd4e5-d42a-4dc0-bed4-36e03bfc6964, data={'support': 10}),
#  Node(tag=603, identifier=c7da2958-7b3b-4066-9b84-d99cec02a9e0, data={'support': 12}),
#  Node(tag=607, identifier=736dd572-21e2-40f7-87f2-ef42a01a9846, data={'support': 12}),
#  Node(tag=616, identifier=a4c52835-d834-4307-be75-153884607a2d, data={'support': 6}),
#  Node(tag=619, identifier=8a7cfe6d-1943-488b-a0d4-39e32fe1e796, data={'support': 18}),
#  Node(tag=624, identifier=576e29f7-ab97-4905-ab68-6d0366c2be30, data={'support': 15}),
#  Node(tag=628, identifier=cfd28c37-f640-4ff8-bea9-d159cc4bd87b, data={'support': 26}),
#  Node(tag=19462, identifier=ab5f3c60-e7b5-48e0-9a23-dad2dbc86a2f, data={'support': 8}),
#  Node(tag=3860, identifier=91cc8724-2371-456a-aae8-4e38c1a347ca, data={'support': 6}),
#  Node(tag=4148, identifier=24bf34c9-ff21-43ab-a819-646b5ebdf234, data={'support': 6}),
#  Node(tag=13406, identifier=6b0049bd-f422-4838-a1ac-d1fee1711012, data={'support': 5}),
#  Node(tag=11882, identifier=aa3c9d73-a43f-4978-8524-3fab1c710612, data={'support': 5}),
#  Node(tag=16521, identifier=f53f441f-d4d4-4d5a-bf2e-1a1c2ac6e8c7, data={'support': 5}),
#  Node(tag=14491, identifier=62f63227-b230-48bb-83da-151130ecb225, data={'support': 5}),
#  Node(tag=2730, identifier=1a86acc0-10bb-4f63-a2a0-d07dec24148f, data={'support': 5}),
#  Node(tag=3860, identifier=c19bfa52-5360-434a-a2ba-126b4feadf4e, data={'support': 7}),
#  Node(tag=16708, identifier=eba3dd06-0d60-4d3e-9800-6418ea5361fc, data={'support': 5}),
#  Node(tag=13670, identifier=ba641c2f-e171-4a37-9872-3d70cce2e792, data={'support': 5}),
#  Node(tag=11133, identifier=9877dabb-983e-426f-831d-1cb13bace046, data={'support': 5}),
#  Node(tag=8600, identifier=c8e0f304-e3be-41b2-b138-0a9c29d203a1, data={'support': 7}),
#  Node(tag=18361, identifier=8ba66e1c-2368-4c1a-a1b5-a0c7edb00653, data={'support': 7}),
#  Node(tag=2508, identifier=3b9c50e1-a12a-42d1-9d0f-54cafd355fa0, data={'support': 5}),
#  Node(tag=18404, identifier=4eb0a74e-5835-422b-8e0a-b3430bbb26db, data={'support': 5}),
#  Node(tag=635, identifier=61a9aaa9-e93f-4307-b3ea-268cfe44acbe, data={'support': 8}),
#  Node(tag=637, identifier=73fe6425-d62b-4a74-abd6-4b017ab1c152, data={'support': 14}),
#  Node(tag=641, identifier=f7adc9ca-b99f-43df-a0f3-e511d2e5c244, data={'support': 15}),
#  Node(tag=645, identifier=83007110-6c8c-4af5-a8b0-120b04115ec3, data={'support': 11}),
#  Node(tag=647, identifier=9a3354d9-26a4-4e6c-9e1e-223b171509e6, data={'support': 6}),
#  Node(tag=648, identifier=0da24fc9-d0d3-4785-a462-730d6ebaa730, data={'support': 67}),
#  Node(tag=15413, identifier=a7cf3907-2193-455c-beb9-2d69663b9ce5, data={'support': 6}),
#  Node(tag=17607, identifier=425287ff-db58-47c5-906d-adcf2f73a0fc, data={'support': 5}),
#  Node(tag=16601, identifier=dd768a26-b2fd-4140-8d2e-149a498df7f9, data={'support': 5}),
#  Node(tag=17652, identifier=c5f286c4-4569-4119-80ec-4f01bf459994, data={'support': 6}),
#  Node(tag=8491, identifier=b19c131e-c60f-478a-99d7-619595fda8dd, data={'support': 6}),
#  Node(tag=2437, identifier=6f1448b2-1e27-452b-b855-1d380625967e, data={'support': 6}),
#  Node(tag=411, identifier=3ab91ec6-a73b-4a71-af8b-557e7dde003b, data={'support': 7}),
#  Node(tag=15771, identifier=dcbdd01d-8a86-440a-b631-a77e5692efe1, data={'support': 5}),
#  Node(tag=16820, identifier=65898185-16fd-490d-82e9-ee67f2721833, data={'support': 5}),
#  Node(tag=2497, identifier=3fd5fd13-3527-45bd-9d74-d73fdb6357fc, data={'support': 6}),
#  Node(tag=5606, identifier=51c4ff41-827a-4f01-a9f6-80492060cbe2, data={'support': 11}),
#  Node(tag=18920, identifier=d193a7e1-b8c2-4abc-8157-6b072b26d3a6, data={'support': 5}),
#  Node(tag=8767, identifier=7cb6a42b-fde0-4b8b-8142-5a1b2a5c6bc6, data={'support': 14}),
#  Node(tag=10848, identifier=fd842bbd-1ad8-4ea8-aca1-6e64714435c4, data={'support': 7}),
#  Node(tag=2674, identifier=0883154c-b728-4970-abad-9565c5833aff, data={'support': 5}),
#  Node(tag=20134, identifier=be5017f1-00ef-4d30-bdac-d8d2931c1557, data={'support': 7}),
#  Node(tag=20172, identifier=85942d09-29e2-4d8a-a120-ca164e4a063b, data={'support': 5}),
#  Node(tag=2780, identifier=b1255b8a-3e64-4d51-83ff-0e45018c747b, data={'support': 5}),
#  Node(tag=8953, identifier=ad6ab3a5-69aa-4e8f-98ec-5936cd5fb19c, data={'support': 5}),
#  Node(tag=2912, identifier=772d5244-7c3a-4673-8da4-814c26b4dffe, data={'support': 5}),
#  Node(tag=868, identifier=2c370738-fb37-4a6c-9084-bdfbc7610bb7, data={'support': 7}),
#  Node(tag=2997, identifier=9c5dde20-3fa7-4af2-a3e7-84bae3309879, data={'support': 7}),
#  Node(tag=8145, identifier=7936947b-73c3-487d-abce-d121abc89e24, data={'support': 5}),
#  Node(tag=14322, identifier=6e3d6813-37aa-4780-83e4-f24dad22ce9d, data={'support': 5}),
#  Node(tag=18428, identifier=9d55464d-ec66-43dd-a6b0-30058d32c4ce, data={'support': 5}),
#  Node(tag=653, identifier=aeac0811-28a5-4ffd-87b2-99b814d4f040, data={'support': 15}),
#  Node(tag=658, identifier=e10fcbba-ceb5-4a02-90ab-45b00b21bdb8, data={'support': 10}),
#  Node(tag=660, identifier=76bde6ff-2bd2-4918-8582-7042ab7f1ada, data={'support': 40}),
#  Node(tag=11357, identifier=f536b4bb-d919-4180-a7cf-f8d603d1495d, data={'support': 6}),
#  Node(tag=3790, identifier=e9788459-63ed-48a2-8586-08739b950af9, data={'support': 7}),
#  Node(tag=5100, identifier=9534b3d2-86f8-47f8-a577-8b1cc9a1fe26, data={'support': 5}),
#  Node(tag=662, identifier=27845cc6-433c-4719-8ee2-a0bcf1e1e178, data={'support': 23}),
#  Node(tag=17324, identifier=da188362-65e2-4710-b82f-e0a85eddf7e6, data={'support': 5}),
#  Node(tag=663, identifier=fc453f82-3cff-4297-aa36-62bd2735f65c, data={'support': 61}),
#  Node(tag=20501, identifier=6e6a810a-2518-4491-8348-23f716113c1e, data={'support': 5}),
#  Node(tag=5149, identifier=d99a6340-508d-4c84-b805-63491dca9888, data={'support': 5}),
#  Node(tag=9246, identifier=72c8eeb9-c57e-456a-963d-b6e025e28dcf, data={'support': 7}),
#  Node(tag=4253, identifier=997fc6c4-b3e8-4dd1-8bf7-368e30ae353e, data={'support': 5}),
#  Node(tag=3242, identifier=b720cee4-f665-4060-ae3f-93e73a912c67, data={'support': 5}),
#  Node(tag=11451, identifier=1878f562-ce23-4146-8e6f-b70add481d01, data={'support': 5}),
#  Node(tag=8474, identifier=56bf7202-59be-4352-88ec-87eef5c5a030, data={'support': 7}),
#  Node(tag=12600, identifier=85faff41-16a6-4035-9430-fd7dea42ff49, data={'support': 5}),
#  Node(tag=18824, identifier=9b25e919-2d6c-48dd-b32d-d99264f79586, data={'support': 8}),
#  Node(tag=18856, identifier=0b3b372e-17bf-43b5-95b9-9f5dc7a35eae, data={'support': 8}),
#  Node(tag=11688, identifier=3b773ac8-791c-4e95-84ea-ff351eb7cf53, data={'support': 5}),
#  Node(tag=2551, identifier=37dd77e8-35e6-41c4-b156-68a0f3ad63ad, data={'support': 6}),
#  Node(tag=19969, identifier=710f27ae-1202-48a7-8da5-e46e84190e98, data={'support': 8}),
#  Node(tag=6672, identifier=ceaf4378-f521-40bf-bfe4-e9a8be33ff01, data={'support': 6}),
#  Node(tag=4672, identifier=8f9de472-d6ec-49d0-b562-24d6a0b6efd9, data={'support': 6}),
#  Node(tag=10834, identifier=e329954f-3a97-44c0-8648-ff0f966cc016, data={'support': 6}),
#  Node(tag=9834, identifier=a2ad658b-feb6-4f01-b29c-9e1f580524de, data={'support': 10}),
#  Node(tag=17081, identifier=a13ed4f1-1c06-427a-953e-e4565815a20f, data={'support': 6}),
#  Node(tag=1727, identifier=22d8fc25-1be3-474e-8b96-b216f36fe413, data={'support': 6}),
#  Node(tag=19154, identifier=3cf6ac0b-da5e-466a-8935-83f6471053f8, data={'support': 9}),
#  Node(tag=9940, identifier=90d3454c-569f-4477-8186-ac7dc9fabffc, data={'support': 8}),
#  Node(tag=12071, identifier=c46d64e8-4547-40f4-810d-1d6371bf127f, data={'support': 7}),
#  Node(tag=14147, identifier=a3d3df66-a74f-44d3-a1f9-30c478a14dcd, data={'support': 6}),
#  Node(tag=667, identifier=892f3f0d-bc8d-41f8-969c-f730c73fe220, data={'support': 27}),
#  Node(tag=668, identifier=bc50730d-571c-48ad-b1e1-a2d41189198a, data={'support': 12}),
#  Node(tag=676, identifier=e7833af1-5374-4c6e-8f38-72df7eaa4187, data={'support': 5}),
#  Node(tag=682, identifier=de4ca271-113a-4235-bb3a-0b5f9e9c2f8f, data={'support': 17}),
#  Node(tag=687, identifier=479b9c35-097c-4afc-905f-35b2587caed7, data={'support': 5}),
#  Node(tag=688, identifier=efa1f058-6be3-4983-861b-2c4c0050a8a0, data={'support': 6}),
#  Node(tag=689, identifier=36f6cc0b-4b7d-44bb-93a4-8f3d8c3aa1cc, data={'support': 15}),
#  Node(tag=693, identifier=12caa49a-e042-4e16-a45c-99122f4fa7b4, data={'support': 6}),
#  Node(tag=694, identifier=1ec521ff-63c5-4210-b07c-768e6b69dec3, data={'support': 8}),
#  Node(tag=697, identifier=20562a37-41cc-4886-a5e3-c912a4652883, data={'support': 7}),
#  Node(tag=699, identifier=c6444359-cc3a-4a16-8249-9b5a73be45b9, data={'support': 27}),
#  Node(tag=700, identifier=f60e147a-b927-4793-bac9-256daf9198f6, data={'support': 12}),
#  Node(tag=702, identifier=3d52cbaa-3939-45f1-aaf9-9e2fd7391375, data={'support': 5}),
#  Node(tag=713, identifier=2e6e8a0a-279d-4a92-a6e4-3a0eaf755a64, data={'support': 7}),
#  Node(tag=719, identifier=6b1742ce-c243-4e75-8a87-ae3ad9fd0826, data={'support': 11}),
#  Node(tag=720, identifier=7f9ed226-34bb-4fb6-9e88-fc77b5c26971, data={'support': 6}),
#  Node(tag=723, identifier=05b3c5d3-ef73-47f3-b0fe-65d10daa6648, data={'support': 13}),
#  Node(tag=17926, identifier=0fc6b618-41d6-4c2b-8643-e74b611d65b8, data={'support': 5}),
#  Node(tag=724, identifier=f00bde9a-c86f-4438-992a-1bf3eb516087, data={'support': 19}),
#  Node(tag=19646, identifier=e28ae183-2f91-44d6-971c-2e75598753a6, data={'support': 5}),
#  Node(tag=20247, identifier=66292992-1b55-407f-93c6-2925192db0d8, data={'support': 5}),
#  Node(tag=12071, identifier=3a4a0a22-3fa1-49d4-994c-2b71692cb60d, data={'support': 5}),
#  Node(tag=725, identifier=806c1399-92e3-4fbf-b5fd-833b79766017, data={'support': 12}),
#  Node(tag=734, identifier=a0c0bff9-6c78-4b1a-804f-65407d37861f, data={'support': 7}),
#  Node(tag=740, identifier=ece4643f-f84b-4260-920c-1cdf43db740e, data={'support': 14}),
#  Node(tag=747, identifier=eefe2759-b340-459b-a4ef-7135a75e7505, data={'support': 8}),
#  Node(tag=17311, identifier=5cc01d6e-880a-436d-b5f9-f1fd1e5029c6, data={'support': 6}),
#  Node(tag=2024, identifier=f3269d36-cf57-4c15-8af7-5566bb9095d2, data={'support': 6}),
#  Node(tag=748, identifier=dbda9b28-d32c-4274-982e-52dfa00b5e0c, data={'support': 6}),
#  Node(tag=749, identifier=6e9e162d-3514-45cc-9809-9c9e7ca91263, data={'support': 6}),
#  Node(tag=751, identifier=e859692e-f411-4eba-928b-4513a7f5abb1, data={'support': 17}),
#  Node(tag=752, identifier=ebb3a96e-2345-49aa-bc70-d1c717018f15, data={'support': 7}),
#  Node(tag=755, identifier=c2c67b70-8fed-4045-b4fe-c7f26bd1d2c5, data={'support': 10}),
#  Node(tag=769, identifier=dfd07480-366e-4345-b3d2-90f80bdbb6cd, data={'support': 16}),
#  Node(tag=770, identifier=54db07fc-93c3-4695-a6f4-6c095d57b347, data={'support': 5}),
#  Node(tag=778, identifier=976c4673-efd9-4a7a-9864-f0662eeaf255, data={'support': 20}),
#  Node(tag=15670, identifier=ba27a4e1-927d-4fd8-9145-6146ea0b2d3b, data={'support': 5}),
#  Node(tag=7092, identifier=b82b16c2-3c1c-4f53-bf86-f25481c30f4f, data={'support': 5}),
#  Node(tag=781, identifier=ead1bdc0-d2b6-40f4-857b-fe27e69aef62, data={'support': 13}),
#  Node(tag=18381, identifier=b60177d1-9d48-430d-9cd0-3e3c4476977a, data={'support': 5}),
#  Node(tag=784, identifier=28039be3-73fd-48cf-828c-45e9cdd7d33b, data={'support': 6}),
#  Node(tag=787, identifier=689983b4-934b-4e5d-b4dc-03775b1ceca7, data={'support': 6}),
#  Node(tag=793, identifier=efd4de15-623f-4d05-82af-65d31e06e622, data={'support': 11}),
#  Node(tag=794, identifier=99401f79-f8fc-4c27-bd3b-cc2a054f8a22, data={'support': 10}),
#  Node(tag=797, identifier=55b6c9ad-a650-41fc-b4ee-7d54d8453abf, data={'support': 64}),
#  Node(tag=10269, identifier=85d046cf-d338-4166-910e-65fbde52de33, data={'support': 13}),
#  Node(tag=20169, identifier=e64f1c28-e60c-4f2c-9f09-afb18fac7114, data={'support': 5}),
#  Node(tag=19602, identifier=3ace2330-da0b-4216-98c0-f866c42f91fb, data={'support': 6}),
#  Node(tag=15542, identifier=ace57f80-cea2-4ad8-932f-e81e875295b0, data={'support': 5}),
#  Node(tag=6444, identifier=b65d3bd3-e4e9-41c5-b508-a9a9908fca03, data={'support': 5}),
#  Node(tag=7475, identifier=eed00de6-d319-4e49-989d-215d5001ade7, data={'support': 5}),
#  Node(tag=7506, identifier=62d1b741-f4d8-46ad-9e04-f81a52a643de, data={'support': 5}),
#  Node(tag=10591, identifier=9b7b32cc-330f-42ec-b684-5a94e3ec556a, data={'support': 5}),
#  Node(tag=10711, identifier=80bfc6ab-429e-4545-a7eb-6c390805c55c, data={'support': 6}),
#  Node(tag=5606, identifier=0c4d6764-2091-4636-8fc4-f6b8501933ec, data={'support': 5}),
#  Node(tag=16905, identifier=07fb611d-b0b2-4789-acdb-18cf01ec0822, data={'support': 8}),
#  Node(tag=8767, identifier=d677681d-0a42-43c1-85a0-79cba8d8af3a, data={'support': 5}),
#  Node(tag=10848, identifier=b62840f1-7352-44c1-bef1-8adc9fd39b42, data={'support': 6}),
#  Node(tag=8866, identifier=9e35cb20-7bd3-4c44-90c7-6d52aa2bf502, data={'support': 5}),
#  Node(tag=1714, identifier=69699cef-789a-4477-8d66-e644389fd4fd, data={'support': 6}),
#  Node(tag=5831, identifier=7c0e3487-35fb-4255-95ab-12f7d4f75fa8, data={'support': 5}),
#  Node(tag=20169, identifier=7bc0cfce-ead9-42c0-b8f4-461aec618e71, data={'support': 8}),
#  Node(tag=20172, identifier=98d52fdc-9438-4cba-a4dc-2073bd763433, data={'support': 6}),
#  Node(tag=3830, identifier=a6c30f26-9ef1-4de9-ac1e-31f14f29c813, data={'support': 7}),
#  Node(tag=15204, identifier=3d63247b-675a-4278-9ec4-0de5d375524e, data={'support': 5}),
#  Node(tag=19431, identifier=d2419f3e-6605-43d1-a3f7-5fe39bab930c, data={'support': 5}),
#  Node(tag=12284, identifier=bc24fd4d-eea7-4bb6-8c52-6a601cf363c1, data={'support': 8}),
#  Node(tag=800, identifier=8680369d-5715-4dcf-ae08-8957fc236be0, data={'support': 16}),
#  Node(tag=801, identifier=5a0afca2-1b61-4451-a6b9-80418c223263, data={'support': 5}),
#  Node(tag=816, identifier=b840fd15-80c1-4ca7-9337-d578906e305b, data={'support': 6}),
#  Node(tag=817, identifier=6a1af1b6-28ec-4a3d-a0b2-120a8eb70031, data={'support': 22}),
#  Node(tag=820, identifier=d4e55c7e-375b-4001-8d24-d60ed2fae971, data={'support': 5}),
#  Node(tag=822, identifier=87d84a09-69c4-4481-9ba3-2f74c108c670, data={'support': 8}),
#  Node(tag=830, identifier=b397e4d1-e658-4b2c-8546-68a296476aa7, data={'support': 27}),
#  Node(tag=840, identifier=ddd32a12-c3c0-4323-8971-f8230f67d0eb, data={'support': 7}),
#  Node(tag=845, identifier=261a3b74-7187-4efb-aa46-57aa7ac567c4, data={'support': 8}),
#  Node(tag=849, identifier=455bb0b0-ac03-4d25-9f63-429ca912842c, data={'support': 19}),
#  Node(tag=855, identifier=e44d65ee-ab88-47a1-a495-df6055bf71cf, data={'support': 13}),
#  Node(tag=9826, identifier=007a9e70-565f-40a7-b0ba-79bde124821a, data={'support': 5}),
#  Node(tag=865, identifier=65658eb1-7562-49e7-b5f7-ab441850e3fa, data={'support': 13}),
#  Node(tag=7323, identifier=62426edd-f91d-4bdf-baac-6c96090df131, data={'support': 6}),
#  Node(tag=868, identifier=35fb2daf-53ac-48ce-831a-3a1ee03dceec, data={'support': 73}),
#  Node(tag=5141, identifier=ce98f631-b494-4838-8e6d-1f49edb7af73, data={'support': 7}),
#  Node(tag=1111, identifier=495fd7d7-e9d3-40a8-a879-0181947cf59b, data={'support': 11}),
#  Node(tag=16494, identifier=3b4f8da0-a222-470d-8298-332953eeef49, data={'support': 6}),
#  Node(tag=16502, identifier=b84f8e5b-88fd-46e3-8a3b-498e39f40b21, data={'support': 6}),
#  Node(tag=1149, identifier=c2a764ee-aabb-49b2-9499-c5d0a8046f03, data={'support': 5}),
#  Node(tag=12488, identifier=a2293898-c242-432e-a60e-c5d30e132696, data={'support': 5}),
#  Node(tag=12510, identifier=a3255f6a-cdde-4064-ad75-1099cefb1714, data={'support': 6}),
#  Node(tag=2272, identifier=f2deea88-fa0c-462c-a059-85a856b5e80e, data={'support': 5}),
#  Node(tag=8491, identifier=605c2a74-6e6c-4853-83ee-3d842f753151, data={'support': 5}),
#  Node(tag=1422, identifier=b6185fca-c2ec-4432-8b5b-6f6630913ebf, data={'support': 5}),
#  Node(tag=411, identifier=1b6eb309-ec74-4041-ab53-b9a7b1be6a8a, data={'support': 7}),
#  Node(tag=16820, identifier=e60ffba5-fd7d-4ace-88bd-a7a9cef8555f, data={'support': 5}),
#  Node(tag=2497, identifier=153fa381-7755-4146-98c4-d240a35d60b2, data={'support': 5}),
#  Node(tag=10711, identifier=a0770780-519e-4199-a190-388cfc0f2870, data={'support': 7}),
#  Node(tag=3556, identifier=e8772c9f-9004-4cc2-aa58-034a3a8f0a68, data={'support': 5}),
#  Node(tag=5606, identifier=916177f7-e50d-45ab-ac77-c6c387b08e64, data={'support': 10}),
#  Node(tag=14826, identifier=8d35f62b-1c3b-4dec-889b-b03300b5a1c5, data={'support': 7}),
#  Node(tag=1523, identifier=cfbc5cc6-4eeb-4e6e-afb6-6dcd12a06139, data={'support': 5}),
#  Node(tag=3617, identifier=fcaab84d-afbc-4f94-85d8-188036562a74, data={'support': 5}),
#  Node(tag=10848, identifier=ace0ad45-7183-4cbb-bf2e-0f6c6e67ec2b, data={'support': 12}),
#  Node(tag=648, identifier=e999027b-e300-48f0-a492-d76df55a4cae, data={'support': 6}),
#  Node(tag=11943, identifier=cede1a53-da4d-4255-be7a-b25c2eea94c0, data={'support': 6}),
#  Node(tag=20172, identifier=8fe6d97f-b130-4437-8b56-b2f6b26d4409, data={'support': 7}),
#  Node(tag=15187, identifier=8e0dace3-413e-4035-9c9f-3ff17f9aaeeb, data={'support': 5}),
#  Node(tag=4949, identifier=12ec0ec0-8be3-4e8d-b9ef-c89bbde06a64, data={'support': 5}),
#  Node(tag=2997, identifier=92ad2a68-c6ff-4f8e-82e2-d3d00a36815e, data={'support': 11}),
#  Node(tag=8145, identifier=d10cc7d7-ccf3-4ee1-8999-d5c76874466d, data={'support': 13}),
#  Node(tag=869, identifier=6fdf767c-5003-481e-8080-792ef43d84c4, data={'support': 5}),
#  Node(tag=877, identifier=b8dc0d05-c98d-4091-ac72-7ad3a9296f09, data={'support': 38}),
#  Node(tag=17530, identifier=b8850716-bb3e-410d-b2c3-737bf945d503, data={'support': 5}),
#  Node(tag=2489, identifier=5f58eda3-6de1-47c7-bb05-fe95b6f1fc81, data={'support': 5}),
#  Node(tag=8172, identifier=383582a2-68b0-4368-a586-fc9b0bf67d87, data={'support': 5}),
#  Node(tag=888, identifier=0d2347d8-a944-4bae-89d4-a2d8c03b4ffb, data={'support': 9}),
#  Node(tag=892, identifier=d4c8e550-1344-4325-9e16-e905a8f74de1, data={'support': 5}),
#  Node(tag=894, identifier=bc7d4307-d969-4d21-bfcb-3b82c501a5f2, data={'support': 44}),
#  Node(tag=8229, identifier=41a019b4-4d63-42d6-ba65-088eb60592f3, data={'support': 5}),
#  Node(tag=19055, identifier=27991a5e-efbb-4f8a-a70f-cdaf8b15f9ba, data={'support': 5}),
#  Node(tag=11896, identifier=217d41f7-2f77-47b3-bfb4-2a0087608f3e, data={'support': 5}),
#  Node(tag=17597, identifier=c769315f-61e8-4c87-b0f2-3febf09e140d, data={'support': 5}),
#  Node(tag=6892, identifier=04fb22ee-0790-45c6-96a3-23751f5e98f3, data={'support': 5}),
#  Node(tag=8956, identifier=37177165-d11c-459b-9be5-8a1d15c02a39, data={'support': 5}),
#  Node(tag=3347, identifier=9630cb0c-07d6-42a0-a47c-9736969984e1, data={'support': 5}),
#  Node(tag=7485, identifier=835fb5a5-5f37-4745-9047-0cb63bcdd4e0, data={'support': 5}),
#  Node(tag=14758, identifier=c587b3c5-f690-4311-aa1b-f58b9def6535, data={'support': 6}),
#  Node(tag=898, identifier=ceb86092-4f1d-48ec-9955-4f421bfea58d, data={'support': 13}),
#  Node(tag=904, identifier=fdccda67-337f-4e80-ae43-fee2b34ff0d1, data={'support': 11}),
#  Node(tag=909, identifier=97558182-944d-4031-8f98-3a42e5df273d, data={'support': 14}),
#  Node(tag=913, identifier=79fa7757-74c2-4976-b4e7-0581ca7cdaa3, data={'support': 48}),
#  Node(tag=2887, identifier=5e12ad3c-3115-4c53-80d6-54b908c816c1, data={'support': 5}),
#  Node(tag=1014, identifier=9530e4ae-3641-46d9-9db2-b349be1d0c6f, data={'support': 6}),
#  Node(tag=18424, identifier=d5e595a3-4eec-49b6-b3c9-ff98c27da2db, data={'support': 5}),
#  Node(tag=918, identifier=6ca4d8f9-0a70-4e03-b860-21daa1854ed4, data={'support': 6}),
#  Node(tag=920, identifier=030dd471-f6ef-4765-bffa-fc020f50019f, data={'support': 8}),
#  Node(tag=942, identifier=083f50ac-3fba-4bdb-9856-e864df93b9fd, data={'support': 9}),
# ...
#  Node(tag=1383, identifier=d4419233-baa9-4fe5-9964-87dac5497e47, data={'support': 5}),
#  Node(tag=1385, identifier=f555fe58-325e-443a-a29e-8e99967467ae, data={'support': 24}),
#  Node(tag=553, identifier=083e4c58-5929-4f43-92e3-1cfac1b474f7, data={'support': 5}),
#  Node(tag=4926, identifier=cf8907d6-9953-484a-9472-b9dabe273881, data={'support': 7}),
#  Node(tag=11870, identifier=e99dab3d-2f7b-4c40-9b03-756f875f0cef, data={'support': 8}),
#  Node(tag=10910, identifier=5e2d4cec-5a5f-4cae-8fca-f01632c343b1, data={'support': 5}),
#  Node(tag=12919, identifier=78f9860f-e681-4b5a-bdb3-379825b85501, data={'support': 7}),
#  Node(tag=10910, identifier=98fd316d-43b1-42fe-8111-400fbf3b26c6, data={'support': 6}),
#  Node(tag=19396, identifier=c0c11584-9345-49de-8f8f-885675843119, data={'support': 5}),
#  Node(tag=9205, identifier=97413dfa-7cf2-431a-90d6-6587d595e5d3, data={'support': 6}),
#  Node(tag=1386, identifier=802d3dd1-640c-4575-86f8-78fdd4da9a34, data={'support': 12}),
#  Node(tag=1391, identifier=0f425532-2ea0-48e6-b9c1-15cb7351d780, data={'support': 8}),
#  Node(tag=1393, identifier=a63b4738-fc68-4d38-bf30-53bd83260ab9, data={'support': 9}),
#  Node(tag=1394, identifier=aad8d10a-5001-44c5-8776-465ace97237a, data={'support': 8}),
#  Node(tag=1398, identifier=17437285-7bcc-4da4-8449-937f35937df2, data={'support': 24}),
#  Node(tag=4009, identifier=62bd1cae-f7b0-4ebb-9132-989cee136097, data={'support': 5}),
#  Node(tag=9705, identifier=0aa5173c-6a95-4898-ba0c-7ab82ea8cb02, data={'support': 5}),
#  Node(tag=1411, identifier=5e2b00c9-8c45-458a-a814-3b0f1e136c8d, data={'support': 6}),
#  Node(tag=1415, identifier=94729745-7b93-48f5-be6f-d5ca1e97089b, data={'support': 11}),
#  Node(tag=1420, identifier=7ce6d5ff-568c-42a7-bb72-aaaf101c2e96, data={'support': 10}),
#  Node(tag=1421, identifier=345cb898-74fd-4c7d-a245-ae77849b42ae, data={'support': 5}),
#  Node(tag=1422, identifier=06c7e256-1921-4468-9e01-aba2c2c87982, data={'support': 45}),
#  Node(tag=5141, identifier=ca26ae65-1b49-444d-9eb6-a9faf3f7f3b9, data={'support': 9}),
#  Node(tag=1111, identifier=2b5084c7-22d9-44e5-afc0-016861f7795b, data={'support': 7}),
#  Node(tag=10848, identifier=cdded2dc-6a96-457e-a91f-2172aa3ed2cd, data={'support': 5}),
#  Node(tag=2151, identifier=5619885a-68bf-4601-9faa-2d2a0b725643, data={'support': 5}),
#  Node(tag=16494, identifier=9d9f3bbf-aa1b-478a-a8c2-b6697f25e37c, data={'support': 5}),
#  Node(tag=8866, identifier=87743944-6456-492b-a3e7-723658fb554d, data={'support': 5}),
#  Node(tag=11943, identifier=7da8634d-2d7f-44f3-9348-40e1521a74ca, data={'support': 6}),
#  Node(tag=12510, identifier=772abdb8-3f16-480c-bcd5-17116eaaf7f7, data={'support': 5}),
#  Node(tag=868, identifier=72a2820c-1c12-4c8d-b65f-ef9eb4135cf0, data={'support': 6}),
#  Node(tag=4514, identifier=3d945632-8df1-40c2-803e-3ef6852877af, data={'support': 6}),
#  Node(tag=963, identifier=ca64065f-474c-4c3c-86a9-272e0ba0bff6, data={'support': 5}),
#  Node(tag=2018, identifier=7035f7ae-1737-4d4d-8d2c-0021296b2e9b, data={'support': 6}),
#  Node(tag=5606, identifier=2c91230e-cd51-4ec0-859b-b2ab983e1b46, data={'support': 5}),
#  Node(tag=14826, identifier=581c7f42-4fcf-451d-a265-db4f3fb83db1, data={'support': 8}),
#  Node(tag=5141, identifier=1251216d-7067-4501-bbdd-67a08ad8a915, data={'support': 5}),
#  Node(tag=1523, identifier=3fe9a884-5b8a-47fa-9b50-5721e53f35b0, data={'support': 5}),
#  Node(tag=1427, identifier=d38e04db-48c6-48c2-b8bc-1fe4d9198f26, data={'support': 19}),
#  Node(tag=15431, identifier=937312c7-1eed-4bc7-9516-a9eb5958830b, data={'support': 5}),
#  Node(tag=1428, identifier=c704dd3c-b32f-4837-b11e-f2c85d494bd3, data={'support': 6}),
#  Node(tag=1434, identifier=38eeb866-6858-48e8-889c-1e71388d2862, data={'support': 18}),
#  Node(tag=5815, identifier=03572113-35a1-406a-9416-7fd4ae0d6cb1, data={'support': 6}),
#  Node(tag=1435, identifier=68ad0c84-b7d6-41b5-948c-eb8c571db482, data={'support': 6}),
#  Node(tag=1441, identifier=2c30d3c4-b5e4-47f9-a320-6b6358edeb96, data={'support': 7}),
#  Node(tag=1442, identifier=6649c16a-bb7c-46f8-9c00-e57899563543, data={'support': 19}),
#  Node(tag=1443, identifier=9a89e0d6-87f8-4da1-87c3-43ed1255ef24, data={'support': 14}),
#  Node(tag=1444, identifier=38f364e2-0eb2-4682-b2ff-640f52bf657d, data={'support': 10}),
#  Node(tag=1460, identifier=6bf55338-5ec0-4ee6-b1c0-d8ebfcbb8d2a, data={'support': 19}),
#  Node(tag=1461, identifier=ddf8fe01-0443-4548-a033-21023eaa1d82, data={'support': 12}),
#  Node(tag=1463, identifier=42c04d56-8d42-4976-a1d4-345538234824, data={'support': 14}),
#  Node(tag=1466, identifier=31c132cc-04cd-4f8d-8d78-32bea1617ddf, data={'support': 12}),
#  Node(tag=1472, identifier=449f4ac6-f0e2-4c6f-9428-ecba52ebbadd, data={'support': 10}),
#  Node(tag=1473, identifier=09b84918-4ef4-46b9-b99a-c4f355ce0db1, data={'support': 29}),
#  Node(tag=9441, identifier=9f4ff690-9d62-4224-be9c-d7224a512d6b, data={'support': 6}),
#  Node(tag=14213, identifier=8d14b2c9-0456-4505-ae34-2e4536999373, data={'support': 5}),
#  Node(tag=1476, identifier=6147590a-8c2a-4189-8696-8199c12402dd, data={'support': 34}),
#  Node(tag=14907, identifier=93c4eee6-82f3-4bd6-8ed7-93ee258aa811, data={'support': 7}),
#  Node(tag=15029, identifier=05f0031c-22eb-4c0d-8cbf-9f1f393394b5, data={'support': 5}),
#  Node(tag=3860, identifier=224185aa-4623-4acb-93bf-ffc6d3884fff, data={'support': 5}),
#  Node(tag=9173, identifier=6ca1f8c7-1071-499c-9da5-211acaaeabbc, data={'support': 5}),
#  Node(tag=1482, identifier=f0674a00-8cc5-44c2-90b8-d31c5b98a604, data={'support': 24}),
#  Node(tag=1486, identifier=56158911-3981-40ab-a8da-88e7bcacefdf, data={'support': 15}),
#  Node(tag=1487, identifier=0afb26ba-3464-4b38-8cba-22f8f0e28fbd, data={'support': 7}),
#  Node(tag=1489, identifier=0d219a81-6baf-4b76-afc5-b57931fbf4ee, data={'support': 47}),
#  Node(tag=16494, identifier=548fd6b6-c078-4359-8a99-65d4998c0273, data={'support': 5}),
#  Node(tag=6823, identifier=42700f5f-2621-4f4a-82bf-cc98f7216d0a, data={'support': 7}),
#  Node(tag=13129, identifier=5962407c-7707-48d7-bf30-77e351df9be0, data={'support': 5}),
#  Node(tag=2980, identifier=4cad32b3-7351-4354-853a-e626a14c295f, data={'support': 7}),
#  Node(tag=7085, identifier=01c4410f-dce6-44c8-8e1c-f87abfad23ec, data={'support': 5}),
#  Node(tag=5606, identifier=1fc2f550-4fed-4952-a9ef-1e7bea3e0e75, data={'support': 5}),
#  Node(tag=14322, identifier=0adbcdc1-b420-4899-b3f3-662e657763fd, data={'support': 8}),
#  Node(tag=1494, identifier=dc0a8028-f6d7-407d-9e0e-aedd0baeebd5, data={'support': 8}),
#  Node(tag=1502, identifier=0bb75558-0cd0-4586-a380-b25d7528367d, data={'support': 15}),
#  Node(tag=1508, identifier=4e494b52-febe-4fc3-a310-f7155550fdb5, data={'support': 5}),
#  Node(tag=1510, identifier=d78d51a4-a2b9-4ac9-8d86-b90d20d42cda, data={'support': 5}),
#  Node(tag=1513, identifier=004c486d-098f-4b68-bbe8-02654411497b, data={'support': 9}),
#  Node(tag=1523, identifier=82485093-d1e1-4982-b4c1-be1d62e0da95, data={'support': 36}),
#  Node(tag=1111, identifier=b2c3d669-1e39-4f53-bb67-5bd3879e7884, data={'support': 5}),
#  Node(tag=17584, identifier=c553d900-6738-4e3d-9f25-38633a8c2655, data={'support': 5}),
#  Node(tag=1714, identifier=44b69817-cb8b-4dd1-819f-be78d70d8576, data={'support': 6}),
#  Node(tag=1525, identifier=85bffc2a-1e4f-4fce-a752-8a760c5cc046, data={'support': 15}),
#  Node(tag=1530, identifier=18df7a88-4ed9-4a15-81e7-c2bb20a4c32c, data={'support': 9}),
#  Node(tag=5296, identifier=e7acd794-7c8d-4fe9-b2aa-7cebdde085fe, data={'support': 5}),
#  Node(tag=1534, identifier=3f82eba7-ab15-4612-9ad4-53b0fa7c493e, data={'support': 20}),
#  Node(tag=11366, identifier=08d13bd7-49ef-4056-b337-6c98d5fcd339, data={'support': 6}),
#  Node(tag=1537, identifier=e6cac8fe-3478-4d82-8fe8-11a48d4fd519, data={'support': 15}),
#  Node(tag=15053, identifier=7153a539-a00f-40a9-8224-66bc5a3bb45a, data={'support': 5}),
#  Node(tag=1543, identifier=51f3baa2-7580-49ec-9842-934d9b522799, data={'support': 5}),
#  Node(tag=1547, identifier=733249c6-c02b-4c3b-a1db-45da74cf4838, data={'support': 11}),
#  Node(tag=1548, identifier=39b79e1b-c4d9-4164-8624-6554d9d17ff8, data={'support': 8}),
#  Node(tag=1550, identifier=0e769e48-12a6-42a6-90f5-cf958f72e5f0, data={'support': 7}),
#  Node(tag=1569, identifier=2f4a39d2-be1b-4a45-b08a-7c573ad22201, data={'support': 6}),
#  Node(tag=1580, identifier=4111e3ab-5bfd-4ac5-bedf-c6eb0bba24b7, data={'support': 15}),
#  Node(tag=1587, identifier=73acfbc2-cfef-4585-bf26-6a61af311db2, data={'support': 29}),
#  Node(tag=16866, identifier=a63b8f58-48c1-471e-9e88-50597d555723, data={'support': 5}),
#  Node(tag=1588, identifier=222db7af-c0d7-4453-b195-a0cf19e9f1ce, data={'support': 9}),
#  Node(tag=1590, identifier=57e2adf3-9dbb-455a-86b0-484629d08418, data={'support': 11}),
#  Node(tag=1591, identifier=428d34e0-5155-45ff-8167-aa129521332d, data={'support': 34}),
#  Node(tag=2272, identifier=11b34d94-de68-4d39-9ed8-b7f7f53b0738, data={'support': 6}),
#  Node(tag=20263, identifier=28e06f04-acb6-44bb-b4a1-0c8516871ad9, data={'support': 7}),
#  Node(tag=13216, identifier=515961db-a00d-4366-923f-4a500046400c, data={'support': 5}),
#  Node(tag=1595, identifier=9f0bc489-c144-4f9e-8d7c-7af5b5e70b48, data={'support': 13}),
#  Node(tag=1596, identifier=f2642f02-7871-469f-bac3-1e5064de65de, data={'support': 5}),
#  Node(tag=1600, identifier=60500391-f0f6-4853-a90c-536bfd50ad8e, data={'support': 6}),
#  Node(tag=1605, identifier=2ad529be-c5f9-4a75-b114-ed6574819f74, data={'support': 25}),
#  Node(tag=15893, identifier=fb7ca06b-316f-4f5c-a6cf-d51914c6cf71, data={'support': 5}),
#  Node(tag=1618, identifier=8c6ee5ed-9214-4976-b813-fb9b6b6c4fb4, data={'support': 5}),
#  Node(tag=1623, identifier=598df926-3476-409c-b91c-d982371f67a3, data={'support': 5}),
#  Node(tag=1626, identifier=b33e1105-7d70-4c63-9673-7803a72b2dad, data={'support': 26}),
#  Node(tag=1627, identifier=5fa243da-fa7c-476e-bb8b-c6e33a78b3f8, data={'support': 10}),
#  Node(tag=1635, identifier=e2e0e5f2-dde9-4847-86d2-3813726db1e1, data={'support': 40}),
#  Node(tag=16471, identifier=484e9d3e-1a02-40bd-9838-54d5b9e67c81, data={'support': 5}),
#  Node(tag=15578, identifier=7aeb722e-c223-4c32-bfd6-307bd60d450b, data={'support': 6}),
#  Node(tag=3295, identifier=ae531c3c-4b8f-4825-920d-c54a4c85024b, data={'support': 5}),
#  Node(tag=10496, identifier=6a1de7cb-b6d6-40b5-8564-923c282bdde7, data={'support': 6}),
#  Node(tag=8488, identifier=50eebe4e-63b5-4c48-805a-db321fea0dfe, data={'support': 5}),
#  Node(tag=12597, identifier=85bab06d-fedc-4304-8676-ded83133d161, data={'support': 5}),
#  Node(tag=6522, identifier=67add477-cbcc-443b-8c02-b981587a01bc, data={'support': 5}),
#  Node(tag=381, identifier=75de114a-e776-45a4-b8d4-f3ba73047b34, data={'support': 6}),
#  Node(tag=3460, identifier=69577adc-ecd8-45e9-863a-ca517bf8bac3, data={'support': 7}),
#  Node(tag=5725, identifier=8a7e7d5b-ed55-4b9a-b1d1-473dcf6a6ec6, data={'support': 6}),
#  Node(tag=3460, identifier=73b79144-bb3c-4f65-869b-bf3f3bdeec42, data={'support': 5}),
#  Node(tag=8488, identifier=613e9cb5-aea8-442a-96d3-b0b4de1ee883, data={'support': 5}),
#  Node(tag=20141, identifier=54c2fbfc-71b5-4408-8920-4c72e62782a9, data={'support': 6}),
#  Node(tag=6892, identifier=fc7f5fb0-84e2-49d7-9aa7-6ea3457b0c01, data={'support': 5}),
#  Node(tag=1640, identifier=f35c0d6f-61cc-4926-82f3-2a52fc1417d9, data={'support': 12}),
#  Node(tag=1641, identifier=b90cfa34-ac06-44ce-89f4-996a32da28dd, data={'support': 76}),
#  Node(tag=12393, identifier=0bc2ebdc-061a-4445-b26a-ac12028a48ac, data={'support': 6}),
#  Node(tag=18743, identifier=c5777e6b-6cfb-4591-8d8e-cb20a620deca, data={'support': 5}),
#  Node(tag=8749, identifier=0a8268c4-c9f4-45fa-90a4-467ce1397732, data={'support': 5}),
#  Node(tag=5679, identifier=d443f828-31a3-4d4d-a4ea-25116d22a57a, data={'support': 7}),
#  Node(tag=19075, identifier=bb1a2e60-bfb9-4f06-8ddc-3a3c3ddd5f77, data={'support': 8}),
#  Node(tag=4745, identifier=a357eeab-c734-48fa-8ec8-0415bd2ff9ec, data={'support': 6}),
#  Node(tag=16100, identifier=7df6f31f-2c6e-422d-beaa-4d26df0f968e, data={'support': 6}),
#  Node(tag=9963, identifier=bd5f2618-f06e-4c39-ad41-8acc5eb28698, data={'support': 7}),
#  Node(tag=15090, identifier=edd2e442-b008-41ad-9ed0-7ed37e0fb87d, data={'support': 7}),
#  Node(tag=8138, identifier=3387c025-89e1-43fe-9c7f-da8a34cdc551, data={'support': 5}),
#  Node(tag=8169, identifier=e63b9921-1357-4445-ad18-c7a9a7d10991, data={'support': 7}),
#  Node(tag=18421, identifier=3066514d-fb1b-437e-858a-90a520bd4ebe, data={'support': 6}),
#  Node(tag=1643, identifier=b0e5f3bc-d84e-4228-bfe6-57b3305f6ee1, data={'support': 5}),
#  Node(tag=1645, identifier=4c44c31a-5d93-47f7-9ebc-c4571d27e613, data={'support': 19}),
#  Node(tag=1653, identifier=db5756b8-5d34-4dec-8ecd-72e4fe38f5bf, data={'support': 10}),
#  Node(tag=1654, identifier=0a6e7f58-bca3-4129-849b-7a28fef197bd, data={'support': 5}),
#  Node(tag=1655, identifier=a9e57ad9-0f69-4045-b8ac-29b734acfd44, data={'support': 5}),
#  Node(tag=1656, identifier=21ee7f24-20f6-4094-9693-1c0f17f51170, data={'support': 19}),
#  Node(tag=1667, identifier=ae8e4f0c-445a-4bf7-a612-f4d01e415535, data={'support': 7}),
#  Node(tag=1674, identifier=c3d3b7cc-0d34-4663-a085-0a3a62dfc775, data={'support': 19}),
#  Node(tag=1678, identifier=607e20c2-d82c-420e-8e4d-543d36f5b0a2, data={'support': 10}),
#  Node(tag=1683, identifier=4e33bb00-55a8-41c8-9369-aae99242ce53, data={'support': 5}),
#  Node(tag=1685, identifier=229b5a5d-4286-4c69-b5a6-b101130e7b55, data={'support': 5}),
#  Node(tag=1687, identifier=f275294c-cae7-4cdf-b578-3b9e4032d70d, data={'support': 17}),
#  Node(tag=1695, identifier=9601d421-dd1b-4ba6-9b98-9fcf6b03aca6, data={'support': 5}),
#  Node(tag=1696, identifier=30775522-f447-4957-ba11-ae9f67e8ce59, data={'support': 8}),
#  Node(tag=1698, identifier=50b07658-6fc7-4970-8df2-30829cb2c430, data={'support': 41}),
#  Node(tag=12910, identifier=68e5f0b9-01e7-4f2e-986d-5d94b7d13968, data={'support': 5}),
#  Node(tag=17114, identifier=6c639bdd-6f53-4e80-98d8-aad853705580, data={'support': 8}),
#  Node(tag=1701, identifier=a8ca81d2-f1da-4d6b-9b1e-4fa6695c0423, data={'support': 15}),
#  Node(tag=1710, identifier=8835aeab-8e5f-43f2-84ff-1b8d1e3cd771, data={'support': 42}),
#  Node(tag=18059, identifier=8f1f3136-274a-461a-b1a9-196ef4853b20, data={'support': 10}),
#  Node(tag=16293, identifier=7442113f-523a-4609-8f43-da4b9f30206a, data={'support': 5}),
#  Node(tag=16297, identifier=a8783e99-2835-4047-ba48-aae3177f9120, data={'support': 9}),
#  Node(tag=6577, identifier=e1bd8158-433e-4d7a-9e73-5fb9ca5addbc, data={'support': 5}),
#  Node(tag=1712, identifier=2727c608-e60e-4e86-840a-e72653a07fc6, data={'support': 17}),
#  Node(tag=1713, identifier=b5ba21f5-1dc1-4973-8899-938875c3dccc, data={'support': 27}),
#  Node(tag=1714, identifier=fd44d8fa-9a6e-4898-9f0b-57c832a70072, data={'support': 69}),
#  Node(tag=5141, identifier=1d681497-bcdc-4a4b-8ae9-188b45e7b53c, data={'support': 6}),
#  Node(tag=16494, identifier=59287a0f-773a-4405-a0cc-e239b4a81b8b, data={'support': 5}),
#  Node(tag=12510, identifier=cf489919-f11e-4737-8ef5-6d76781743c6, data={'support': 8}),
#  Node(tag=6444, identifier=8be5da78-a59f-4d67-bfe0-15fa7e1751f6, data={'support': 5}),
#  Node(tag=8539, identifier=8737ead9-1aba-445a-b6a6-c9ac9b18f25b, data={'support': 5}),
#  Node(tag=3519, identifier=52677776-ecc2-4a0c-b19c-f14e41d390d7, data={'support': 5}),
#  Node(tag=16866, identifier=41aa3aae-36fe-4314-945d-4cc85971f475, data={'support': 6}),
#  Node(tag=5606, identifier=04c81e6b-3d83-493d-9d31-79a1c802eb5d, data={'support': 7}),
#  Node(tag=14826, identifier=04649fcc-59bf-4335-9366-8208914dc67e, data={'support': 6}),
#  Node(tag=2627, identifier=d50e91c4-2eda-4305-a592-2d95d51b9a01, data={'support': 7}),
#  Node(tag=10848, identifier=de5d25c0-d523-4436-beb7-d70084c9bd67, data={'support': 5}),
#  Node(tag=20169, identifier=e3d9cf7b-56a6-410b-97bd-bdca819e2fff, data={'support': 6}),
#  Node(tag=15090, identifier=f681275f-bbdc-4ffe-9295-691956a482a9, data={'support': 5}),
#  Node(tag=4910, identifier=ecccfc36-2d2a-4f40-b9f6-1a25df67a500, data={'support': 6}),
#  Node(tag=2018, identifier=a5d46c4c-a650-4d7c-b576-c41ad12084ef, data={'support': 5}),
#  Node(tag=1715, identifier=1a667333-219d-4adb-8b68-c0382b226939, data={'support': 10}),
#  ...]
