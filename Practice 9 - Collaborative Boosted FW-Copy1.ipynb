# %% [markdown]
# # Recommender Systems 2018/19
#
# ### Practice 9 - Collaborative Boosted FW
#
#
# ### Underlying idea... the way to capture the feature importance from the user point of view, is to... use its point of view (e.g., ratings, collaborative similarity)

# %% [markdown]
# ## A few info about feature weightign techniques
#
# * Information retrieval methods (TF-IDF, BM25..) do not optimize a predictive model
# * Embedding methods (FISM, UFSM, Factorization Machines) optimize everything at the same time, model and weights, but are difficult to train and sensitive to noise
# * Wrapper methods (LFW, CFW) apply a two step approach approximating an already built collaborative model, more robust and easier to tune

# %% [markdown]
# from urllib.request import urlretrieve
# import zipfile
#
# # skip the download
# #urlretrieve ("http://files.grouplens.org/datasets/movielens/ml-10m.zip", "data/Movielens_10M/movielens_10m.zip")
# dataFile = zipfile.ZipFile("data/Movielens_10M/movielens_10m.zip")
# URM_path = dataFile.extract("ml-10M100K/ratings.dat", path = "data/Movielens_10M")
# URM_file = open(URM_path, 'r')
#
#
# def rowSplit (rowString):
#
#     split = rowString.split("::")
#     split[3] = split[3].replace("\n","")
#
#     split[0] = int(split[0])
#     split[1] = int(split[1])
#     split[2] = float(split[2])
#     split[3] = int(split[3])
#
#     result = tuple(split)
#
#     return result
#
#
# URM_file.seek(0)
# URM_tuples = []
#
# for line in URM_file:
#    URM_tuples.append(rowSplit (line))
#
# userList, itemList, ratingList, timestampList = zip(*URM_tuples)
#
# userList = list(userList)
# itemList = list(itemList)
# ratingList = list(ratingList)
# timestampList = list(timestampList)
#
# import scipy.sparse as sps
#
# URM_all = sps.coo_matrix((ratingList, (userList, itemList)))
# URM_all = URM_all.tocsr()

# %% [markdown]
# ICM_path = dataFile.extract("ml-10M100K/tags.dat", path = "data/Movielens_10M")
# ICM_file = open(ICM_path, 'r')
#
# def rowSplit (rowString):
#     split = rowString.split("::")
#     split[3] = split[3].replace("\n","")
#
#     split[0] = int(split[0])
#     split[1] = int(split[1])
#     split[2] = str(split[2]) # tag is a string, not a float like the rating
#     split[3] = int(split[3])
#
#     result = tuple(split)
#
#     return result
#
# ICM_file.seek(0)
# ICM_tuples = []
#
# for line in ICM_file:
#     ICM_tuples.append(rowSplit(line))
#
# userList_icm, itemList_icm, tagList_icm, timestampList_icm = zip(*ICM_tuples)
#
# userList_icm = list(userList_icm)
# itemList_icm = list(itemList_icm)
# tagList_icm = list(tagList_icm)
# timestampList_icm = list(timestampList_icm)
#
# userList_unique = list(set(userList_icm))
# itemList_unique = list(set(itemList_icm))
# tagList_unique = list(set(tagList_icm))
#
# numUsers = len(userList_unique)
# numItems = len(itemList_unique)
# numTags = len(tagList_unique)
#
#
# print ("Number of items\t {}, Number of users\t {}".format(numItems, numUsers))
# print ("Number of tags\t {}, Number of item-tag tuples {}".format(numTags, len(tagList_icm)))
#
# print("\nData example:")
# print(userList_icm[0:10])
# print(itemList_icm[0:10])
# print(tagList_icm[0:10])
#
#
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# le.fit(tagList_icm)
#
# tagList_icm = le.transform(tagList_icm)
#
# import numpy as np
#
# ones = np.ones(len(tagList_icm))
#
# ICM_all = sps.coo_matrix((ones, (itemList_icm, tagList_icm)), shape=(URM_all.shape[1], tagList_icm.max()+1))
# ICM_all = ICM_all.tocsr()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
# %matplotlib inline
# import src.utils.build_icm as build_icm
import scipy.sparse as sps
from src.utils.data_splitter import train_test_holdout, train_test_user_holdout, train_test_row_holdout
# from src.utils.evaluation import evaluate_algorithm, evaluate_algorithm_recommendations
# from src.utils.top_n_idx_sparse import top_n_idx_sparse
# from src.utils.Compute_Similarity_Python import Compute_Similarity_Python
# from src.libs.similarity import cosine
# import src.utils.similarity_wrapper as sim
# import time
import src.utils.build_icm as build_icm

import sys
sys.path.append('src/libs/RecSys_Course_2018')

# %%
JUPYTER = True
sys.path.append('src/data/')

# #### Load data
if JUPYTER:
    # Jupyter
    tracks_csv_file = "../../../data/tracks.csv"
    interactions_csv_file = "../../../data/train.csv"
    playlist_id_csv_file = "../../../data/target_playlists.csv"
    sequential_csv_file = "../../../data/train_sequential.csv"
else:
    # PyCharm
    tracks_csv_file = "data/tracks.csv"
    interactions_csv_file = "data/train.csv"
    playlist_id_csv_file = "data/target_playlists.csv"
    sequential_csv_file = "data/train_sequential.csv"

tracks_df = pd.read_csv(tracks_csv_file)
interactions_df = pd.read_csv(interactions_csv_file)
playlist_id_df = pd.read_csv(playlist_id_csv_file)
train_sequential_df = pd.read_csv(sequential_csv_file)
userList = interactions_df["playlist_id"]
itemList = interactions_df["track_id"]
ratingList = np.ones(interactions_df.shape[0])
targetsList = playlist_id_df["playlist_id"]
targetsListOrdered = targetsList[:5000].tolist()
targetsListCasual = targetsList[5000:].tolist()
userList_unique = pd.unique(userList)
itemList_unique = tracks_df["track_id"]
numUsers = len(userList_unique)
numItems = len(itemList_unique)
numberInteractions = interactions_df.size

# #### Build URM

URM_all = sps.coo_matrix((ratingList, (userList, itemList)))
URM_all_csr = URM_all.tocsr()

# #### Train/test split: ratings and user holdout

# %%
ICM_all = build_icm.build_icm(tracks_df, split_duration_lenght=800, feature_weights={'albums': 1, 'artists': 0.5, 'durations': 0.1})
ICM_all = ICM_all.tocsr()

# %%
seed = 0
# ratings holdout
# URM_train, URM_test_pred = train_test_holdout(URM_all, train_perc=0.8, seed=seed)
# URM_test_known = None

# user holdout
# URM_train, URM_test_known, URM_test_pred = train_test_user_holdout(URM_all, user_perc=0.8, train_perc=0.8, seed=seed)

# row holdout
URM_train, URM_test_pred = train_test_row_holdout(URM_all, userList_unique, train_sequential_df, train_perc=0.8, seed=seed, targetsListOrdered=targetsListOrdered, nnz_threshold=10)
URM_test_known = None

# row holdout - validation
# URM_train_val, URM_test_pred = train_test_row_holdout(URM_all, userList_unique, train_sequential_df, train_perc=0.8,
#                                                       seed=seed, targetsListOrdered=targetsListOrdered,
#                                                       nnz_threshold=10)
# URM_train, URM_valid = train_test_holdout(URM_train_val, train_perc=0.7, seed=seed)
# URM_test_known = None

URM_train = URM_train
# URM_validation = URM_valid
URM_test = URM_test_pred

# %%
best_params_ItemKNNCF = {'topK': 700, 'shrink': 200, 'similarity': 'cosine', 'normalize': True}
best_params_ItemKNNCBF = {'topK': 500, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True}

# %% [markdown]
# ### Step 1: Create the two models, collaborative and content based

# %%
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender


itemKNNCF = ItemKNNCFRecommender(URM_train)
itemKNNCF.fit(**best_params_ItemKNNCF)

itemKNNCBF = ItemKNNCBFRecommender(ICM_all, URM_train)
itemKNNCBF.fit(**best_params_ItemKNNCBF)
# Out:
# Similarity column 20635 ( 100 % ), 1404.85 column/sec, elapsed time 0.24 min
# Similarity column 20635 ( 100 % ), 725.61 column/sec, elapsed time 0.47 min

# %% [markdown]
# ### Question, how the two similarities differ?

# %%
W_sparse_CF = itemKNNCF.W_sparse
W_sparse_CBF = itemKNNCBF.W_sparse

# %% [markdown]
# ## Let's plt the global similarity distribution

# %%
W_sparse_CF_sorted = np.sort(W_sparse_CF.data.copy())
W_sparse_CBF_sorted = np.sort(W_sparse_CBF.data.copy())

# %%
import numpy as np
import matplotlib.pyplot as pyplot


pyplot.plot(W_sparse_CF_sorted, label = 'CF')
pyplot.plot(W_sparse_CBF_sorted, label = 'CBF')
pyplot.ylabel('Similarity cell ')
pyplot.xlabel('Similarity value')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## Let's now plot the delta for the common values

# %%
# Get common structure
W_sparse_CF_structure = W_sparse_CF.copy()
W_sparse_CF_structure.data = np.ones_like(W_sparse_CF_structure.data)

W_sparse_CBF_structure = W_sparse_CBF.copy()
W_sparse_CBF_structure.data = np.ones_like(W_sparse_CBF_structure.data)

W_sparse_common = W_sparse_CF_structure.multiply(W_sparse_CBF_structure)

# Get values of both in common structure of CF
W_sparse_delta = W_sparse_CBF.copy().multiply(W_sparse_common)
W_sparse_delta -= W_sparse_CF.copy().multiply(W_sparse_common)

# %%
W_sparse_delta_sorted = np.sort(W_sparse_delta.data.copy())

# %%
pyplot.plot(W_sparse_delta_sorted, label = 'delta')
pyplot.ylabel('Similarity cell ')
pyplot.xlabel('Similarity value')
pyplot.legend()
pyplot.show()

# %%
# How many values we have in common?

print("W_sparse_CF has {:.2E} values and {:.2f} % in common with CBF".format(W_sparse_CF.nnz, W_sparse_common.nnz/W_sparse_CF.nnz*100))
print("W_sparse_CBF has {:.2E} values and {:.2f} % in common with CF".format(W_sparse_CBF.nnz, W_sparse_common.nnz/W_sparse_CBF.nnz*100))

print("W_sparse_delta has {:.2E} values".format(W_sparse_delta.nnz))
# Out:
# W_sparse_CF has 6.33E+06 values and 4.45 % in common with CBF
# W_sparse_CBF has 1.03E+07 values and 2.74 % in common with CF
# W_sparse_delta has 2.82E+05 values

# %% [markdown]
# ## What do we see?
# ## The great majority of similarities are not common... the models are modeling two very different phenomena

# %% [markdown]
# # Idea:
#
# ## what if we were to weight features in such a way to approximate as well as possible the collaborative similarity?
#
# ### Basic model:  $S_{CBF} = ICM \cdot diag(feature\_weights) \cdot ICM^{T}$
#
#
# ### We want  $S_{CBF} = S_{CF}$
#
# ### Hence we wish to find the weights such that  $S_{CF} = ICM \cdot diag(feature\_weights) \cdot ICM^{T}$
#
# ### Now, we can rearrange the equations considering that we need only weights for features the two items have in common... this becomes a regression problem in form Ax = b. In our case A are the common features, x the weights and b the collaborative similarity

# %% [markdown]
# ### Since it is a regression problem, we can use an already available solver like linalg in scipy.sparse
#
# ### It takes as imput two data structures, one is sparse and the other is the target value

# %%
W_sparse_delta = W_sparse_delta.tocoo()


item_index_1 = W_sparse_delta.row[666]
item_index_2 = W_sparse_delta.col[666]

# %%
print("Item indices are {} and {}".format(item_index_1, item_index_2))
# Out:
# Item indices are 93 and 16630

# %%
print("Collaborative similarity value is {}".format(W_sparse_CF[item_index_1, item_index_2]))
print("Content-based similarity value is {}".format(W_sparse_CBF[item_index_1, item_index_2]))
# Out:
# Collaborative similarity value is 0.016511112451553345
# Content-based similarity value is 0.00025967281544581056

# %% [markdown]
# ### Compute the common features

# %%
common_features = ICM_all[item_index_1,:].multiply(ICM_all[item_index_2,:])
common_features
# Out:
# <1x19416 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
common_features.indices
# Out:
# array([16526, 19412], dtype=int32)

# %% [markdown]
# ## These items have just a common feature, that is a common scenario
#
# ### Let's look for items having  a few features in common, say 5

# %%
min_common_features = 5

for inner_index in range(len(W_sparse_delta.row)):

    item_index_1 = W_sparse_delta.row[inner_index]
    item_index_2 = W_sparse_delta.col[inner_index]

    common_features = ICM_all[item_index_1,:].multiply(ICM_all[item_index_2,:])
    
    if common_features.nnz >= min_common_features:
        
        # Bad programming, don't do this at home
        break

    print("Item indices are {} and {}".format(item_index_1, item_index_2))

    print("Collaborative similarity value is {}".format(W_sparse_CF[item_index_1, item_index_2]))
    print("Content-based similarity value is {}".format(W_sparse_CBF[item_index_1, item_index_2]))

    common_features.indices
# Out:
# Item indices are 0 and 7894
# Collaborative similarity value is 0.004639158025383949
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 15
# Collaborative similarity value is 0.026661183685064316
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 855
# Collaborative similarity value is 0.04558618366718292
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 3967
# Collaborative similarity value is 0.004333560820668936
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 4429
# Collaborative similarity value is 0.013528835959732533
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 5432
# Collaborative similarity value is 0.04150218144059181
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 5676
# Collaborative similarity value is 0.022852443158626556
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 5805
# Collaborative similarity value is 0.01468271017074585
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 6887
# Collaborative similarity value is 0.013656704686582088
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 8379
# Collaborative similarity value is 0.004692304879426956
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 9171
# Collaborative similarity value is 0.04168623313307762
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 9474
# Collaborative similarity value is 0.01679006591439247
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 9826
# Collaborative similarity value is 0.06636976450681686
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 9977
# Collaborative similarity value is 0.009384609758853912
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 10721
# Collaborative similarity value is 0.016870912164449692
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 11585
# Collaborative similarity value is 0.023068057373166084
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 12382
# Collaborative similarity value is 0.024175306782126427
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 12403
# Collaborative similarity value is 0.031299859285354614
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 14088
# Collaborative similarity value is 0.05579836294054985
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 14508
# Collaborative similarity value is 0.003987341187894344
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 14985
# Collaborative similarity value is 0.004692304879426956
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 15877
# Collaborative similarity value is 0.004187704063951969
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 16801
# Collaborative similarity value is 0.03814908117055893
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 17278
# Collaborative similarity value is 0.008456292562186718
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 17352
# Collaborative similarity value is 0.004530289676040411
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 17685
# Collaborative similarity value is 0.01830267906188965
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 18142
# Collaborative similarity value is 0.05494092032313347
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 18481
# Collaborative similarity value is 0.004575669765472412
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 18947
# Collaborative similarity value is 0.01564689911901951
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 19491
# Collaborative similarity value is 0.02287834882736206
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1 and 19702
# Collaborative similarity value is 0.004404568113386631
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 20122
# Collaborative similarity value is 0.01708865351974964
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1 and 20294
# Collaborative similarity value is 0.004000960849225521
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 2312
# Collaborative similarity value is 0.007747800555080175
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 2867
# Collaborative similarity value is 0.00462696235626936
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 3067
# Collaborative similarity value is 0.009327392093837261
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 3169
# Collaborative similarity value is 0.008889679796993732
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 5664
# Collaborative similarity value is 0.0163631159812212
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 6054
# Collaborative similarity value is 0.007302153389900923
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 6589
# Collaborative similarity value is 0.009129135869443417
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 7421
# Collaborative similarity value is 0.009188493713736534
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 7515
# Collaborative similarity value is 0.012748216278851032
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 7748
# Collaborative similarity value is 0.008350840769708157
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 8155
# Collaborative similarity value is 0.004594246856868267
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 8191
# Collaborative similarity value is 0.004465950187295675
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 10477
# Collaborative similarity value is 0.004594246856868267
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 11200
# Collaborative similarity value is 0.009327392093837261
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 11243
# Collaborative similarity value is 0.008525758050382137
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 11696
# Collaborative similarity value is 0.012788637541234493
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 11877
# Collaborative similarity value is 0.004564567934721708
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 12610
# Collaborative similarity value is 0.008739562705159187
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 12618
# Collaborative similarity value is 0.013656139373779297
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 13032
# Collaborative similarity value is 0.004444839898496866
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 13784
# Collaborative similarity value is 0.007420011796057224
# Content-based similarity value is 0.0012584143551066518
# Item indices are 2 and 14066
# Collaborative similarity value is 0.004305723123252392
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 14180
# Collaborative similarity value is 0.012788637541234493
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 15617
# Collaborative similarity value is 0.014642108231782913
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 16009
# Collaborative similarity value is 0.004594246856868267
# Content-based similarity value is 0.00025967281544581056
# Item indices are 2 and 16331
# Collaborative similarity value is 0.012683207169175148
# Content-based similarity value is 0.0012584143551066518
# Item indices are 2 and 20591
# Collaborative similarity value is 0.00462696235626936
# Content-based similarity value is 0.00025967281544581056
# Item indices are 3 and 1777
# Collaborative similarity value is 0.004380503203719854
# Content-based similarity value is 0.00025967281544581056
# Item indices are 3 and 6024
# Collaborative similarity value is 0.023478424176573753
# Content-based similarity value is 0.0012584143551066518
# Item indices are 3 and 7369
# Collaborative similarity value is 0.0046889688819646835
# Content-based similarity value is 0.00025967281544581056
# Item indices are 3 and 10537
# Collaborative similarity value is 0.018339306116104126
# Content-based similarity value is 0.0012584143551066518
# Item indices are 3 and 13560
# Collaborative similarity value is 0.004580216016620398
# Content-based similarity value is 0.00025967281544581056
# Item indices are 3 and 13758
# Collaborative similarity value is 0.01927865855395794
# Content-based similarity value is 0.0012584143551066518
# Item indices are 3 and 14026
# Collaborative similarity value is 0.004748721141368151
# Content-based similarity value is 0.00025967281544581056
# Item indices are 4 and 2796
# Collaborative similarity value is 0.019186006858944893
# Content-based similarity value is 0.0012584143551066518
# Item indices are 4 and 3469
# Collaborative similarity value is 0.033140022307634354
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 4108
# Collaborative similarity value is 0.024045715108513832
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 4601
# Collaborative similarity value is 0.019138755276799202
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 5222
# Collaborative similarity value is 0.009645598009228706
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 5236
# Collaborative similarity value is 0.023627374321222305
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 6877
# Collaborative similarity value is 0.023923445492982864
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 8411
# Collaborative similarity value is 0.018772583454847336
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 10168
# Collaborative similarity value is 0.02386784926056862
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 10649
# Collaborative similarity value is 0.014230375178158283
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 11608
# Collaborative similarity value is 0.02367144264280796
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 11754
# Collaborative similarity value is 0.037107739597558975
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 12004
# Collaborative similarity value is 0.019094279035925865
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 12385
# Collaborative similarity value is 0.028352847322821617
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 12514
# Collaborative similarity value is 0.028779009357094765
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 12583
# Collaborative similarity value is 0.03731561079621315
# Content-based similarity value is 0.0012584143551066518
# Item indices are 4 and 13651
# Collaborative similarity value is 0.028352847322821617
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 14184
# Collaborative similarity value is 0.028158875182271004
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 14986
# Collaborative similarity value is 0.032002195715904236
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 16266
# Collaborative similarity value is 0.02376512810587883
# Content-based similarity value is 0.0012584143551066518
# Item indices are 4 and 17473
# Collaborative similarity value is 0.028518153354525566
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 18006
# Collaborative similarity value is 0.03230223059654236
# Content-based similarity value is 0.0010087289847433567
# Item indices are 4 and 20245
# Collaborative similarity value is 0.03715796396136284
# Content-based similarity value is 0.0010087289847433567
# Item indices are 5 and 2185
# Collaborative similarity value is 0.0048667192459106445
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 4285
# Collaborative similarity value is 0.013258622027933598
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 7761
# Collaborative similarity value is 0.004041478969156742
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 8906
# Collaborative similarity value is 0.004620395600795746
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 9398
# Collaborative similarity value is 0.01614535041153431
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 9665
# Collaborative similarity value is 0.004535272717475891
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 11457
# Collaborative similarity value is 0.004662191960960627
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 11850
# Collaborative similarity value is 0.0132501982152462
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 15970
# Collaborative similarity value is 0.0041130646131932735
# Content-based similarity value is 0.00025967281544581056
# Item indices are 5 and 20226
# Collaborative similarity value is 0.035440824925899506
# Content-based similarity value is 0.00025967281544581056
# Item indices are 7 and 3990
# Collaborative similarity value is 0.03204554691910744
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 4432
# Collaborative similarity value is 0.008773304522037506
# Content-based similarity value is 0.00025967281544581056
# Item indices are 7 and 5987
# Collaborative similarity value is 0.06424085795879364
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 9793
# Collaborative similarity value is 0.014173546805977821
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 11938
# Collaborative similarity value is 0.06862354278564453
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 14365
# Collaborative similarity value is 0.014081967994570732
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 16360
# Collaborative similarity value is 0.014173546805977821
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 17481
# Collaborative similarity value is 0.021557537838816643
# Content-based similarity value is 0.00025967281544581056
# Item indices are 7 and 17602
# Collaborative similarity value is 0.018666915595531464
# Content-based similarity value is 0.0012584143551066518
# Item indices are 7 and 19494
# Collaborative similarity value is 0.05787535011768341
# Content-based similarity value is 0.0012584143551066518
# Item indices are 9 and 1405
# Collaborative similarity value is 0.0048667192459106445
# Content-based similarity value is 0.00025967281544581056
# Item indices are 9 and 3504
# Collaborative similarity value is 0.004746600985527039
# Content-based similarity value is 0.0012584143551066518
# Item indices are 9 and 7918
# Collaborative similarity value is 0.009493201971054077
# Content-based similarity value is 0.00025967281544581056
# Item indices are 9 and 12083
# Collaborative similarity value is 0.004839492030441761
# Content-based similarity value is 0.00025967281544581056
# Item indices are 9 and 16675
# Collaborative similarity value is 0.009551973082125187
# Content-based similarity value is 0.00025967281544581056
# Item indices are 9 and 17580
# Collaborative similarity value is 0.00928949099034071
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 573
# Collaborative similarity value is 0.014222708530724049
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 625
# Collaborative similarity value is 0.014150943607091904
# Content-based similarity value is 0.0012584143551066518
# Item indices are 10 and 675
# Collaborative similarity value is 0.00917431153357029
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 778
# Collaborative similarity value is 0.02424268238246441
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 1382
# Collaborative similarity value is 0.012197278439998627
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 1746
# Collaborative similarity value is 0.021027076989412308
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 2046
# Collaborative similarity value is 0.004573419690132141
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 2109
# Collaborative similarity value is 0.009708737954497337
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 2845
# Collaborative similarity value is 0.004676034674048424
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 3252
# Collaborative similarity value is 0.008726420812308788
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 4632
# Collaborative similarity value is 0.004216769710183144
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 4946
# Collaborative similarity value is 0.008980060927569866
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 5453
# Collaborative similarity value is 0.013378003612160683
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 5903
# Collaborative similarity value is 0.019382435828447342
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 6059
# Collaborative similarity value is 0.009160432033240795
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 6354
# Collaborative similarity value is 0.004560227505862713
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 6475
# Collaborative similarity value is 0.009202997200191021
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 7092
# Collaborative similarity value is 0.016387343406677246
# Content-based similarity value is 0.0012584143551066518
# Item indices are 10 and 7538
# Collaborative similarity value is 0.008582018315792084
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 8481
# Collaborative similarity value is 0.016744498163461685
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 8728
# Collaborative similarity value is 0.018190106377005577
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 8911
# Collaborative similarity value is 0.00882580317556858
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 9624
# Collaborative similarity value is 0.016112832352519035
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 9712
# Collaborative similarity value is 0.022681817412376404
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 10070
# Collaborative similarity value is 0.013423138298094273
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 11959
# Collaborative similarity value is 0.013535871170461178
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 13918
# Collaborative similarity value is 0.00931545626372099
# Content-based similarity value is 0.0012584143551066518
# Item indices are 10 and 13980
# Collaborative similarity value is 0.019038427621126175
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 15417
# Collaborative similarity value is 0.004315013065934181
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 15670
# Collaborative similarity value is 0.008230846375226974
# Content-based similarity value is 0.0012584143551066518
# Item indices are 10 and 16381
# Collaborative similarity value is 0.013454226776957512
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 16541
# Collaborative similarity value is 0.009480719454586506
# Content-based similarity value is 0.0012584143551066518
# Item indices are 10 and 17972
# Collaborative similarity value is 0.004535272717475891
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 18716
# Collaborative similarity value is 0.004580216016620398
# Content-based similarity value is 0.00025967281544581056
# Item indices are 10 and 20628
# Collaborative similarity value is 0.014259076677262783
# Content-based similarity value is 0.0012584143551066518
# Item indices are 12 and 616
# Collaborative similarity value is 0.004150218330323696
# Content-based similarity value is 0.0012584143551066518
# Item indices are 12 and 660
# Collaborative similarity value is 0.0241225678473711
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 1026
# Collaborative similarity value is 0.012816489674150944
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 1130
# Collaborative similarity value is 0.011060641147196293
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 1869
# Collaborative similarity value is 0.013727009296417236
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 1919
# Collaborative similarity value is 0.010373773984611034
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 2536
# Collaborative similarity value is 0.0043206182308495045
# Content-based similarity value is 0.0012584143551066518
# Item indices are 12 and 3278
# Collaborative similarity value is 0.01971026323735714
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 3606
# Collaborative similarity value is 0.015076604671776295
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 3790
# Collaborative similarity value is 0.017346365377306938
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 4162
# Collaborative similarity value is 0.008667121641337872
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 5030
# Collaborative similarity value is 0.0043206182308495045
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 5799
# Collaborative similarity value is 0.020411867648363113
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 7925
# Collaborative similarity value is 0.023164507001638412
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 10034
# Collaborative similarity value is 0.01525498740375042
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 17510
# Collaborative similarity value is 0.004628293216228485
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 18138
# Collaborative similarity value is 0.019677355885505676
# Content-based similarity value is 0.00025967281544581056
# Item indices are 12 and 19479
# Collaborative similarity value is 0.016460904851555824
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 1
# Collaborative similarity value is 0.026661183685064316
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 855
# Collaborative similarity value is 0.027397770434617996
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 1719
# Collaborative similarity value is 0.06621061265468597
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 2511
# Collaborative similarity value is 0.0035384006332606077
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 2537
# Collaborative similarity value is 0.003626912832260132
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 3967
# Collaborative similarity value is 0.004085906781256199
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 4429
# Collaborative similarity value is 0.0043170698918402195
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 5432
# Collaborative similarity value is 0.030819788575172424
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 5676
# Collaborative similarity value is 0.017182130366563797
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 5805
# Collaborative similarity value is 0.029472826048731804
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 5920
# Collaborative similarity value is 0.004085906781256199
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 6781
# Collaborative similarity value is 0.004291009157896042
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 6887
# Collaborative similarity value is 0.008748210966587067
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 8379
# Collaborative similarity value is 0.009129135869443417
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 8464
# Collaborative similarity value is 0.05536027252674103
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 9171
# Collaborative similarity value is 0.023253483697772026
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 9176
# Collaborative similarity value is 0.004085906781256199
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 9474
# Collaborative similarity value is 0.027383998036384583
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 9826
# Collaborative similarity value is 0.04344889894127846
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 9977
# Collaborative similarity value is 0.004564567934721708
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 10047
# Collaborative similarity value is 0.009492117911577225
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 10721
# Collaborative similarity value is 0.015750328078866005
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 11119
# Collaborative similarity value is 0.018602591007947922
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 11585
# Collaborative similarity value is 0.01043732464313507
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 12382
# Collaborative similarity value is 0.011107000522315502
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 12403
# Collaborative similarity value is 0.012798920273780823
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 13213
# Collaborative similarity value is 0.004220372531563044
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 13237
# Collaborative similarity value is 0.020000066608190536
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 14088
# Collaborative similarity value is 0.045984864234924316
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 14508
# Collaborative similarity value is 0.0036510766949504614
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 14777
# Collaborative similarity value is 0.07022768259048462
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 15680
# Collaborative similarity value is 0.06506970524787903
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 15874
# Collaborative similarity value is 0.003964330535382032
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 16698
# Collaborative similarity value is 0.05745323374867439
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 16801
# Collaborative similarity value is 0.01189299114048481
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 16820
# Collaborative similarity value is 0.07116001099348068
# Content-based similarity value is 0.0010087289847433567
# Item indices are 15 and 17156
# Collaborative similarity value is 0.004220372531563044
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 17278
# Collaborative similarity value is 0.007901606149971485
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 17352
# Collaborative similarity value is 0.004344686400145292
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 17685
# Collaborative similarity value is 0.008811291307210922
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 18142
# Collaborative similarity value is 0.03918672353029251
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 18481
# Collaborative similarity value is 0.004405645653605461
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 18947
# Collaborative similarity value is 0.02135653607547283
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 19491
# Collaborative similarity value is 0.004405645653605461
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 19702
# Collaborative similarity value is 0.004178297705948353
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 20122
# Collaborative similarity value is 0.01202076580375433
# Content-based similarity value is 0.00025967281544581056
# Item indices are 15 and 20294
# Collaborative similarity value is 0.007335416041314602
# Content-based similarity value is 0.00025967281544581056
# Item indices are 16 and 15297
# Collaborative similarity value is 0.00866773258894682
# Content-based similarity value is 0.00025967281544581056
# Item indices are 16 and 17179
# Collaborative similarity value is 0.012934522703289986
# Content-based similarity value is 0.00025967281544581056
# Item indices are 16 and 18255
# Collaborative similarity value is 0.004466784652322531
# Content-based similarity value is 0.00025967281544581056
# Item indices are 17 and 9654
# Collaborative similarity value is 0.004875693470239639
# Content-based similarity value is 0.0012584143551066518
# Item indices are 17 and 13654
# Collaborative similarity value is 0.004785965196788311
# Content-based similarity value is 0.0012584143551066518
# Item indices are 18 and 2953
# Collaborative similarity value is 0.004975124262273312
# Content-based similarity value is 0.00025967281544581056
# Item indices are 18 and 8740
# Collaborative similarity value is 0.004975124262273312
# Content-based similarity value is 0.00025967281544581056
# Item indices are 19 and 12003
# Collaborative similarity value is 0.0047846888191998005
# Content-based similarity value is 0.0012584143551066518
# Item indices are 19 and 12934
# Collaborative similarity value is 0.00416234415024519
# Content-based similarity value is 0.00025967281544581056
# Item indices are 19 and 16072
# Collaborative similarity value is 0.004350670613348484
# Content-based similarity value is 0.00025967281544581056
# Item indices are 19 and 16439
# Collaborative similarity value is 0.004638467449694872
# Content-based similarity value is 0.00025967281544581056
# Item indices are 19 and 18209
# Collaborative similarity value is 0.0047530257143080235
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 2652
# Collaborative similarity value is 0.032975710928440094
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 5132
# Collaborative similarity value is 0.03125109151005745
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 7951
# Collaborative similarity value is 0.004750862717628479
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 7979
# Collaborative similarity value is 0.004654791206121445
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 14072
# Collaborative similarity value is 0.022528231143951416
# Content-based similarity value is 0.00025967281544581056
# Item indices are 20 and 14574
# Collaborative similarity value is 0.02855849266052246
# Content-based similarity value is 0.00025967281544581056
# Item indices are 21 and 5763
# Collaborative similarity value is 0.00785691849887371
# Content-based similarity value is 0.00025967281544581056
# Item indices are 21 and 8593
# Collaborative similarity value is 0.0039693149738013744
# Content-based similarity value is 0.00025967281544581056
# Item indices are 21 and 19580
# Collaborative similarity value is 0.004044586792588234
# Content-based similarity value is 0.00025967281544581056
# Item indices are 23 and 1593
# Collaborative similarity value is 0.03604338318109512
# Content-based similarity value is 0.00025967281544581056
# Item indices are 23 and 6594
# Collaborative similarity value is 0.032209549099206924
# Content-based similarity value is 0.00025967281544581056
# Item indices are 23 and 12894
# Collaborative similarity value is 0.013304058462381363
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 1508
# Collaborative similarity value is 0.013956048525869846
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 1850
# Collaborative similarity value is 0.12540099024772644
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 2286
# Collaborative similarity value is 0.09011738002300262
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 2400
# Collaborative similarity value is 0.0043268934823572636
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 2447
# Collaborative similarity value is 0.03697754815220833
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 3019
# Collaborative similarity value is 0.007986954413354397
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 4062
# Collaborative similarity value is 0.040421586483716965
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 7743
# Collaborative similarity value is 0.01605178415775299
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 11420
# Collaborative similarity value is 0.06770564615726471
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 14439
# Collaborative similarity value is 0.03485582023859024
# Content-based similarity value is 0.00025967281544581056
# Item indices are 24 and 14686
# Collaborative similarity value is 0.008518429473042488
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 1711
# Collaborative similarity value is 0.009803921915590763
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 1939
# Collaborative similarity value is 0.009724937379360199
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 3936
# Collaborative similarity value is 0.004880453925579786
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 4360
# Collaborative similarity value is 0.009803921915590763
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 4599
# Collaborative similarity value is 0.004819664638489485
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 6834
# Collaborative similarity value is 0.009760907851159573
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 8772
# Collaborative similarity value is 0.004796501714736223
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 8993
# Collaborative similarity value is 0.009803921915590763
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 10712
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 11783
# Collaborative similarity value is 0.009724937379360199
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 12100
# Collaborative similarity value is 0.009760907851159573
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 13072
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 13130
# Collaborative similarity value is 0.009803921915590763
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 13422
# Collaborative similarity value is 0.009571930393576622
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 13541
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 19072
# Collaborative similarity value is 0.004930275492370129
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 19532
# Collaborative similarity value is 0.004930275492370129
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 19554
# Collaborative similarity value is 0.004930275492370129
# Content-based similarity value is 0.00025967281544581056
# Item indices are 25 and 19594
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 20035
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.0012584143551066518
# Item indices are 25 and 20273
# Collaborative similarity value is 0.0048624686896800995
# Content-based similarity value is 0.0012584143551066518
# Item indices are 26 and 2638
# Collaborative similarity value is 0.006839661858975887
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 2658
# Collaborative similarity value is 0.0038097850047051907
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 3049
# Collaborative similarity value is 0.003730115946382284
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 11478
# Collaborative similarity value is 0.013871410861611366
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 15969
# Collaborative similarity value is 0.01625187136232853
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 16460
# Collaborative similarity value is 0.017730602994561195
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 17138
# Collaborative similarity value is 0.06591061502695084
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 19396
# Collaborative similarity value is 0.01998668536543846
# Content-based similarity value is 0.00025967281544581056
# Item indices are 26 and 19975
# Collaborative similarity value is 0.009999332949519157
# Content-based similarity value is 0.00025967281544581056
# Item indices are 27 and 949
# Collaborative similarity value is 0.04726453498005867
# Content-based similarity value is 0.0012584143551066518
# Item indices are 27 and 3813
# Collaborative similarity value is 0.07747455686330795
# Content-based similarity value is 0.0012584143551066518
# Item indices are 27 and 13833
# Collaborative similarity value is 0.04719577729701996
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 1913
# Collaborative similarity value is 0.007020443677902222
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 2144
# Collaborative similarity value is 0.12586669623851776
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 2423
# Collaborative similarity value is 0.06846533715724945
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 2993
# Collaborative similarity value is 0.05934268981218338
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 3022
# Collaborative similarity value is 0.06974794715642929
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 5510
# Collaborative similarity value is 0.021410852670669556
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 5639
# Collaborative similarity value is 0.04337862879037857
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 6788
# Collaborative similarity value is 0.02248791977763176
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 7963
# Collaborative similarity value is 0.04624764248728752
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 7972
# Collaborative similarity value is 0.018560217693448067
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 10854
# Collaborative similarity value is 0.004001762717962265
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 12888
# Collaborative similarity value is 0.03033451735973358
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 13792
# Collaborative similarity value is 0.004486497025936842
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 15269
# Collaborative similarity value is 0.02353949286043644
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 16045
# Collaborative similarity value is 0.03293744474649429
# Content-based similarity value is 0.00025967281544581056
# Item indices are 28 and 16254
# Collaborative similarity value is 0.07907404005527496
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 17494
# Collaborative similarity value is 0.09026443213224411
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 18369
# Collaborative similarity value is 0.04276368021965027
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 19192
# Collaborative similarity value is 0.10626691579818726
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 19871
# Collaborative similarity value is 0.035309236496686935
# Content-based similarity value is 0.0012584143551066518
# Item indices are 28 and 20546
# Collaborative similarity value is 0.01161166187375784
# Content-based similarity value is 0.00025967281544581056
# Item indices are 30 and 4598
# Collaborative similarity value is 0.004740359727293253
# Content-based similarity value is 0.00025967281544581056
# Item indices are 30 and 5264
# Collaborative similarity value is 0.004532274324446917
# Content-based similarity value is 0.00025967281544581056
# Item indices are 30 and 7717
# Collaborative similarity value is 0.004657728131860495
# Content-based similarity value is 0.00025967281544581056
# Item indices are 30 and 12702
# Collaborative similarity value is 0.0048667192459106445
# Content-based similarity value is 0.0012584143551066518
# Item indices are 32 and 153
# Collaborative similarity value is 0.008191389963030815
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 1018
# Collaborative similarity value is 0.05887441709637642
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 2232
# Collaborative similarity value is 0.0646352767944336
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 2945
# Collaborative similarity value is 0.008774681948125362
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 3604
# Collaborative similarity value is 0.017766734585165977
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 6189
# Collaborative similarity value is 0.0421941876411438
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 6335
# Collaborative similarity value is 0.008143089711666107
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 6687
# Collaborative similarity value is 0.05673210322856903
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 7365
# Collaborative similarity value is 0.007928661070764065
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 8044
# Collaborative similarity value is 0.01601928099989891
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 8133
# Collaborative similarity value is 0.0040956949815154076
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 8217
# Collaborative similarity value is 0.012145225889980793
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 9626
# Collaborative similarity value is 0.02204982377588749
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 10155
# Collaborative similarity value is 0.023345505818724632
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 10744
# Collaborative similarity value is 0.016387049108743668
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 10827
# Collaborative similarity value is 0.008191389963030815
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 11036
# Collaborative similarity value is 0.007127010263502598
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 12839
# Collaborative similarity value is 0.004387340974062681
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 12963
# Collaborative similarity value is 0.04431089013814926
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 13452
# Collaborative similarity value is 0.09216292947530746
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 14028
# Collaborative similarity value is 0.008009640499949455
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 14294
# Collaborative similarity value is 0.03257235884666443
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 14573
# Collaborative similarity value is 0.004204943310469389
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 15883
# Collaborative similarity value is 0.008143089711666107
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 16124
# Collaborative similarity value is 0.004305723123252392
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 16987
# Collaborative similarity value is 0.008052387274801731
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 17231
# Collaborative similarity value is 0.015066022053360939
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 17429
# Collaborative similarity value is 0.06847936660051346
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 17931
# Collaborative similarity value is 0.008143089711666107
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 18238
# Collaborative similarity value is 0.024533605203032494
# Content-based similarity value is 0.00025967281544581056
# Item indices are 32 and 19465
# Collaborative similarity value is 0.027117302641272545
# Content-based similarity value is 0.00025967281544581056
# Item indices are 33 and 459
# Collaborative similarity value is 0.014773993752896786
# Content-based similarity value is 0.00025967281544581056
# Item indices are 33 and 886
# ...
# Collaborative similarity value is 0.07390371710062027
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 10003
# Collaborative similarity value is 0.004316775593906641
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 10366
# Collaborative similarity value is 0.007151495665311813
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 10901
# Collaborative similarity value is 0.07366999983787537
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 11407
# Collaborative similarity value is 0.10701672732830048
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 13319
# Collaborative similarity value is 0.00830338429659605
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 13502
# Collaborative similarity value is 0.007848462089896202
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 13708
# Collaborative similarity value is 0.13593825697898865
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1066 and 14871
# Collaborative similarity value is 0.007848462089896202
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 15743
# Collaborative similarity value is 0.00830338429659605
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 15946
# Collaborative similarity value is 0.0038370992988348007
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 16099
# Collaborative similarity value is 0.011637255549430847
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 16848
# Collaborative similarity value is 0.00830338429659605
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 17150
# Collaborative similarity value is 0.04630321264266968
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 17189
# Collaborative similarity value is 0.029053667560219765
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 18460
# Collaborative similarity value is 0.015516340732574463
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 18778
# Collaborative similarity value is 0.004581362474709749
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 18807
# Collaborative similarity value is 0.004427801817655563
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 19760
# Collaborative similarity value is 0.00830338429659605
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1066 and 20373
# Collaborative similarity value is 0.09326020628213882
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1068 and 9233
# Collaborative similarity value is 0.004740359727293253
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 221
# Collaborative similarity value is 0.008523658849298954
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 1899
# Collaborative similarity value is 0.0329086072742939
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 2436
# Collaborative similarity value is 0.047534652054309845
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 3499
# Collaborative similarity value is 0.008032457903027534
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 3683
# Collaborative similarity value is 0.003925074357539415
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 5112
# Collaborative similarity value is 0.06498031318187714
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 6847
# Collaborative similarity value is 0.00635139923542738
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 10041
# Collaborative similarity value is 0.07184338569641113
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 10776
# Collaborative similarity value is 0.044913895428180695
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 12239
# Collaborative similarity value is 0.004545454401522875
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 13368
# Collaborative similarity value is 0.14069706201553345
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 13823
# Collaborative similarity value is 0.014087707735598087
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 13971
# Collaborative similarity value is 0.06738315522670746
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 14173
# Collaborative similarity value is 0.011775222606956959
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 15249
# Collaborative similarity value is 0.004124963190406561
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 15725
# Collaborative similarity value is 0.03928571566939354
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 17034
# Collaborative similarity value is 0.14163696765899658
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1069 and 19386
# Collaborative similarity value is 0.016557365655899048
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1069 and 20472
# Collaborative similarity value is 0.004380503203719854
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1070 and 9149
# Collaborative similarity value is 0.013656704686582088
# Content-based similarity value is 0.0010087289847433567
# Item indices are 1070 and 11991
# Collaborative similarity value is 0.0047846888191998005
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1070 and 14886
# Collaborative similarity value is 0.016672752797603607
# Content-based similarity value is 0.0010087289847433567
# Item indices are 1070 and 16184
# Collaborative similarity value is 0.008982728235423565
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1070 and 19359
# Collaborative similarity value is 0.014289124868810177
# Content-based similarity value is 0.0010087289847433567
# Item indices are 1071 and 109
# Collaborative similarity value is 0.009022973477840424
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 1231
# Collaborative similarity value is 0.02797776460647583
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 1822
# Collaborative similarity value is 0.004580788780003786
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 1874
# Collaborative similarity value is 0.0038954494521021843
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 2032
# Collaborative similarity value is 0.02947244420647621
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 2507
# Collaborative similarity value is 0.0047264378517866135
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 2535
# Collaborative similarity value is 0.004580788780003786
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1071 and 3894
# Collaborative similarity value is 0.006826690398156643
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 4380
# Collaborative similarity value is 0.004580788780003786
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 7481
# Collaborative similarity value is 0.004511486738920212
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1071 and 7537
# Collaborative similarity value is 0.01592879742383957
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 8161
# Collaborative similarity value is 0.007755569647997618
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1071 and 10309
# Collaborative similarity value is 0.004150638822466135
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 10750
# Collaborative similarity value is 0.00431589363142848
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 10894
# Collaborative similarity value is 0.04986494407057762
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 11210
# Collaborative similarity value is 0.012110036797821522
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 11320
# Collaborative similarity value is 0.010190282948315144
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 13229
# Collaborative similarity value is 0.004036678932607174
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 13653
# Collaborative similarity value is 0.015009487047791481
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1071 and 14436
# Collaborative similarity value is 0.01697222888469696
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 14441
# Collaborative similarity value is 0.004260259214788675
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 16615
# Collaborative similarity value is 0.041677772998809814
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 16917
# Collaborative similarity value is 0.00830127764493227
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 16946
# Collaborative similarity value is 0.010706647299230099
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 17834
# Collaborative similarity value is 0.034224733710289
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1071 and 18782
# Collaborative similarity value is 0.011581874452531338
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 18899
# Collaborative similarity value is 0.08037770539522171
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1071 and 20407
# Collaborative similarity value is 0.012538893148303032
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1072 and 2875
# Collaborative similarity value is 0.029109392315149307
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1072 and 9769
# Collaborative similarity value is 0.06641467660665512
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1072 and 12378
# Collaborative similarity value is 0.004192929249256849
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1075 and 3986
# Collaborative similarity value is 0.007621895521879196
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1075 and 8254
# Collaborative similarity value is 0.008062485605478287
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1075 and 15491
# Collaborative similarity value is 0.004264985676854849
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1076 and 1858
# Collaborative similarity value is 0.021351460367441177
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1076 and 9638
# Collaborative similarity value is 0.03144266828894615
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1076 and 10706
# Collaborative similarity value is 0.016557365655899048
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1076 and 12827
# Collaborative similarity value is 0.02451767958700657
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1076 and 14431
# Collaborative similarity value is 0.0049019609577953815
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1076 and 17547
# Collaborative similarity value is 0.02030017040669918
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1076 and 18412
# Collaborative similarity value is 0.02052251622080803
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1077 and 5103
# Collaborative similarity value is 0.013353651389479637
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1077 and 6129
# Collaborative similarity value is 0.016639072448015213
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1077 and 6167
# Collaborative similarity value is 0.004807692486792803
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1077 and 8797
# Collaborative similarity value is 0.00440277811139822
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1077 and 10119
# Collaborative similarity value is 0.008761006407439709
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1078 and 1942
# Collaborative similarity value is 0.013772046193480492
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1078 and 3940
# Collaborative similarity value is 0.008880243636667728
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1078 and 3979
# Collaborative similarity value is 0.020603014156222343
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1078 and 4665
# Collaborative similarity value is 0.01760255917906761
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1078 and 8712
# Collaborative similarity value is 0.012056111358106136
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1078 and 9138
# Collaborative similarity value is 0.0045332713052630424
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1078 and 10570
# Collaborative similarity value is 0.004419912584125996
# Content-based similarity value is 0.0012584143551066518
# Item indices are 1078 and 12908
# Collaborative similarity value is 0.048415638506412506
# Content-based similarity value is 0.00025967281544581056
# Item indices are 1078 and 14190
# Collaborative similarity value is 0.033354535698890686
# Content-based similarity value is 0.0012584143551066518
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-28be80ef6fcd> in <module>
#       6     item_index_2 = W_sparse_delta.col[inner_index]
#       7
# ----> 8     common_features = ICM_all[item_index_1,:].multiply(ICM_all[item_index_2,:])
#       9
#      10     if common_features.nnz >= min_common_features:
#
# ~/anaconda3/envs/recsys_python36/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# ~/anaconda3/envs/recsys_python36/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     379         if stride == 1:
#     380             # for stride == 1, _get_submatrix is ~30% faster than below
# --> 381             row_slice = self._get_submatrix(i, cslice)
#     382
#     383         else:
#
# ~/anaconda3/envs/recsys_python36/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_submatrix(self, row_slice, col_slice)
#     454         shape = (i1 - i0, j1 - j0)
#     455
# --> 456         return self.__class__((data,indices,indptr), shape=shape)
#     457
#     458 def isspmatrix_csr(x):
#
# ~/anaconda3/envs/recsys_python36/lib/python3.6/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      34
#      35         elif isinstance(arg1, tuple):
# ---> 36             if isshape(arg1):
#      37                 # It's a tuple of matrix dimensions (M, N)
#      38                 # create empty matrix
#
# KeyboardInterrupt:

# %%
from scipy.sparse import linalg

loss_tolerance = 1e-6
iteration_limit = 50000
damp_coeff=0.0

W_sparse_CF_value = W_sparse_CF[item_index_1, item_index_2]

# %%
linalg_result = linalg.lsqr(common_features, W_sparse_CF_value, show = False, atol=loss_tolerance, btol=loss_tolerance,
                  iter_lim = iteration_limit, damp=damp_coeff)

# %%
feature_weights = linalg_result[0].copy()
feature_weights
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
feature_weights[common_features.indices]
# Out:
# array([0.01253564, 0.00313391, 0.00012536])

# %% [markdown]
# ### Note that all weights will be zeros except for the features those items have in common, nothing can be learned if a feature is not common
#
# ### If a dataset has a very sparse ICM, this FW method will struggle

# %%
new_CBF_value = common_features.dot(feature_weights)
new_CBF_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7257236055ac> in <module>
# ----> 1 new_CBF_value = common_features.dot(feature_weights)
#       2 new_CBF_value
#
# NameError: name 'feature_weights' is not defined

# %%
print("Collaborative similarity value is {}".format(W_sparse_CF[item_index_1, item_index_2]))
print("Content-based similarity value is {}".format(W_sparse_CBF[item_index_1, item_index_2]))

print("Weighted Content-based similarity value is {}".format(new_CBF_value[0]))
# Out:
# Collaborative similarity value is 0.10406135022640228
# Content-based similarity value is 0.003887253813445568
# Weighted Content-based similarity value is 0.10406135642893984

# %% [markdown]
# ### Note that we learned the CF similarity amost exactly...
#
# ### Warning: 5 common features and 1 similarity value, more parameters than data points, overfitting!
#
# ### if we want to apply this method to the whole dataset we have to compute the common features of all items having a common similarity value. Whe already know who they are, thanks to W_sparse_delta

# %%
from FW_Similarity.CFW_D_Similarity_Linalg import CFW_D_Similarity_Linalg

# %%
CFW_weithing = CFW_D_Similarity_Linalg(URM_train, ICM_all, W_sparse_CF)
CFW_weithing.fit()
# Out:
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 20635 ( 100 % ), 839.30 column/sec, elapsed time 0.41 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.49E-02, nonzero cells 6334304
# CFW_D_Similarity_Linalg: Content S density: 1.45E-02, nonzero cells 6185270
# CFW_D_Similarity_Linalg: Generating train data. Sample 1 ( 0.00 %)
# CFW_D_Similarity_Linalg: Generating train data. Sample 146250 ( 2.36 %)
# CFW_D_Similarity_Linalg: Content S structure has 231242 out of 6185270 ( 3.74%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.93E+03, average is: 1.70E-02, average over all collaborative data is 8.90E-03
# Similarity column 20635 ( 100 % ), 865.52 column/sec, elapsed time 0.40 min

# %%
from Base.Evaluation.Evaluator import SequentialEvaluator

#evaluator_validation = SequentialEvaluator(URM_validation, cutoff_list=[5])
evaluator_test = SequentialEvaluator(URM_test, cutoff_list=[5])

# %%
results_dict, _ = evaluator_test.evaluateRecommender(itemKNNCF)
results_dict
# Out:
# SequentialEvaluator: Processed 9354 ( 23.08% ) in 30.01 seconds. Users per second: 312
# SequentialEvaluator: Processed 19001 ( 46.87% ) in 60.57 seconds. Users per second: 314
# SequentialEvaluator: Processed 29001 ( 71.54% ) in 91.77 seconds. Users per second: 316
# SequentialEvaluator: Processed 38057 ( 93.88% ) in 121.80 seconds. Users per second: 312
# SequentialEvaluator: Processed 40537 ( 100.00% ) in 127.99 seconds. Users per second: 317
# {5: {'ROC_AUC': 0.2481806744455677,
#   'PRECISION': 0.13290574043464506,
#   'RECALL': 0.10658805054736152,
#   'RECALL_TEST_LEN': 0.13290574043464506,
#   'MAP': 0.08694896706163857,
#   'MRR': 0.25169515915501367,
#   'NDCG': 0.11768522525046443,
#   'F1': 0.11830088555863043,
#   'HIT_RATE': 0.5554678441917261,
#   'ARHR': 0.30259433768328714,
#   'NOVELTY': 0.002676050121652135,
#   'DIVERSITY_MEAN_INTER_LIST': 0.9849385506093425,
#   'DIVERSITY_HERFINDAHL': 0.9969828506672931,
#   'COVERAGE_ITEM': 0.16777320087230435,
#   'COVERAGE_USER': 0.803572136542045,
#   'DIVERSITY_GINI': 0.15487999110070322,
#   'SHANNON_ENTROPY': 9.337888544301963}}

# %%
results_dict, _ = evaluator_test.evaluateRecommender(itemKNNCBF)
results_dict
# Out:
# SequentialEvaluator: Processed 11666 ( 28.78% ) in 30.00 seconds. Users per second: 389
# SequentialEvaluator: Processed 24001 ( 59.21% ) in 60.61 seconds. Users per second: 396
# SequentialEvaluator: Processed 36001 ( 88.81% ) in 90.75 seconds. Users per second: 397
# SequentialEvaluator: Processed 40537 ( 100.00% ) in 100.41 seconds. Users per second: 404
# {5: {'ROC_AUC': 0.11963555928328846,
#   'PRECISION': 0.07071317561733607,
#   'RECALL': 0.059072026269020084,
#   'RECALL_TEST_LEN': 0.07071317561733607,
#   'MAP': 0.046639606340434,
#   'MRR': 0.11852052857060431,
#   'NDCG': 0.06165601268966117,
#   'F1': 0.06437052155284642,
#   'HIT_RATE': 0.28620766213582655,
#   'ARHR': 0.1480297834899752,
#   'NOVELTY': 0.003474268730563409,
#   'DIVERSITY_MEAN_INTER_LIST': 0.9982520080880433,
#   'DIVERSITY_HERFINDAHL': 0.9996454764775732,
#   'COVERAGE_ITEM': 0.5067118972619336,
#   'COVERAGE_USER': 0.803572136542045,
#   'DIVERSITY_GINI': 0.3272140633162649,
#   'SHANNON_ENTROPY': 12.133937895626186}}

# %%
results_dict, _ = evaluator_test.evaluateRecommender(CFW_weithing)
results_dict
# Out:
# SequentialEvaluator: Processed 12175 ( 30.03% ) in 30.01 seconds. Users per second: 406
# SequentialEvaluator: Processed 24001 ( 59.21% ) in 60.65 seconds. Users per second: 396
# SequentialEvaluator: Processed 36103 ( 89.06% ) in 90.67 seconds. Users per second: 398
# SequentialEvaluator: Processed 40537 ( 100.00% ) in 100.74 seconds. Users per second: 402
# {5: {'ROC_AUC': 0.13347887937768804,
#   'PRECISION': 0.07521975808109263,
#   'RECALL': 0.062396336361275596,
#   'RECALL_TEST_LEN': 0.07521975808109263,
#   'MAP': 0.04896691774044431,
#   'MRR': 0.13224708291190432,
#   'NDCG': 0.06598504231519232,
#   'F1': 0.06821058750809388,
#   'HIT_RATE': 0.3059427189974591,
#   'ARHR': 0.16116510841946177,
#   'NOVELTY': 0.0032533297074007397,
#   'DIVERSITY_MEAN_INTER_LIST': 0.9954966765275252,
#   'DIVERSITY_HERFINDAHL': 0.9990944237596259,
#   'COVERAGE_ITEM': 0.37586624666828206,
#   'COVERAGE_USER': 0.803572136542045,
#   'DIVERSITY_GINI': 0.23617228637219936,
#   'SHANNON_ENTROPY': 11.129528137620333}}

# %% [markdown]
# ### This algorithm has parameters too:
# * topK, the usual number of neighbors
# * add_zeros_quota, the percentage of zero collaborative similarities to add to the train set, this helps the regressor in finding non-relevant features
# * normalize_similarity, apply or not the usual cosine denominator

# %%
from ParameterTuning.BayesianSearch import BayesianSearch
from ParameterTuning.AbstractClassSearch import DictionaryKeys

from ParameterTuning.AbstractClassSearch import EvaluatorWrapper


evaluator_validation_tuning = EvaluatorWrapper(evaluator_validation)
evaluator_test_tuning = EvaluatorWrapper(evaluator_test)


recommender_class = CFW_D_Similarity_Linalg

parameterSearch = BayesianSearch(recommender_class,
                                 evaluator_validation=evaluator_validation_tuning,
                                 evaluator_test=evaluator_test_tuning)


hyperparamethers_range_dictionary = {}
hyperparamethers_range_dictionary["topK"] = [5, 10, 20, 50, 100, 150, 200, 300, 400, 500, 600, 700, 800]
hyperparamethers_range_dictionary["add_zeros_quota"] = range(0,1)
hyperparamethers_range_dictionary["normalize_similarity"] = [True, False]



recommenderDictionary = {DictionaryKeys.CONSTRUCTOR_POSITIONAL_ARGS: [URM_train, ICM_all, W_sparse_CF],
                         DictionaryKeys.CONSTRUCTOR_KEYWORD_ARGS: {},
                         DictionaryKeys.FIT_POSITIONAL_ARGS: dict(),
                         DictionaryKeys.FIT_KEYWORD_ARGS: dict(),
                         DictionaryKeys.FIT_RANGE_KEYWORD_ARGS: hyperparamethers_range_dictionary}

output_root_path = "result_experiments/"

import os

# If directory does not exist, create
if not os.path.exists(output_root_path):
    os.makedirs(output_root_path)

output_root_path += recommender_class.RECOMMENDER_NAME    
    
    
n_cases = 2
metric_to_optimize = "MAP"

best_parameters_CFW_D = parameterSearch.search(recommenderDictionary,
                                                 n_cases = n_cases,
                                                 output_root_path = output_root_path,
                                                 metric=metric_to_optimize)
# Out:
# Initialization
# --------------------------------------------------------------------------------------
#  Step |   Time |      Value |   add_zeros_quota |   normalize_similarity |      topK |
# BayesianSearch: Testing config: {'topK': 100, 'add_zeros_quota': 0.554339736755939, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8015.05 column/sec, elapsed time 0.14 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 1.47E-04, nonzero cells 624111
# CFW_D_Similarity_Linalg: Content S structure has 176941 out of 624111 ( 28.35%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 9.84E+03, average is: 5.56E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 8082.12 column/sec, elapsed time 0.13 min
# SequentialEvaluator: Processed 30248 ( 43.30% ) in 30.00 seconds. Users per second: 1008
# SequentialEvaluator: Processed 63629 ( 91.08% ) in 60.00 seconds. Users per second: 1060
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 65.40 seconds. Users per second: 1068
# BayesianSearch: New best config found. Config: {'topK': 100, 'add_zeros_quota': 0.554339736755939, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.23251189334402225, 'PRECISION': 0.12500202795230692, 'RECALL': 0.02567822778469299, 'RECALL_TEST_LEN': 0.12500202795230692, 'MAP': 0.07402332622356764, 'MRR': 0.24433676415155742, 'NDCG': 0.04988431943163831, 'F1': 0.04260452746921793, 'HIT_RATE': 0.6223284710193682, 'ARHR': 0.3005773699605592, 'NOVELTY': 0.0007108966812643189, 'DIVERSITY_MEAN_INTER_LIST': 0.874110298247455, 'DIVERSITY_HERFINDAHL': 0.9748195570791022, 'COVERAGE_ITEM': 0.0235514477845672, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.05523756651501048, 'SHANNON_ENTROPY': 6.384996402251202}
#
# BayesianSearch: Saving model in result_experiments/
#
# CFW_D_Similarity_Linalg: Saving model in file 'result_experiments/_best_model'
# CFW_D_Similarity_Linalg: Saving complete
# CFW_D_Similarity_Linalg: Loading model from file 'result_experiments/_best_model'
# CFW_D_Similarity_Linalg: Loading complete
# SequentialEvaluator: Processed 32001 ( 45.80% ) in 30.48 seconds. Users per second: 1050
# SequentialEvaluator: Processed 64680 ( 92.56% ) in 60.48 seconds. Users per second: 1069
# SequentialEvaluator: Processed 69878 ( 100.00% ) in 65.12 seconds. Users per second: 1073
# BayesianSearch: Best result evaluated on URM_test. Config: {'topK': 100, 'add_zeros_quota': 0.554339736755939, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: CUTOFF: 5 - ROC_AUC: 0.3474985, PRECISION: 0.2481146, RECALL: 0.0256617, RECALL_TEST_LEN: 0.2481146, MAP: 0.1740920, MRR: 0.4101472, NDCG: 0.0635737, F1: 0.0465128, HIT_RATE: 1.2405621, ARHR: 0.5979152, NOVELTY: 0.0007109, DIVERSITY_MEAN_INTER_LIST: 0.8741307, DIVERSITY_HERFINDAHL: 0.9748236, COVERAGE_ITEM: 0.0235514, COVERAGE_USER: 0.9763861, DIVERSITY_GINI: 0.0552469, SHANNON_ENTROPY: 6.3852649,
#
#
#     1 | 03m16s |    0.07402 |            0.5543 |                 0.8860 |    4.3510 |
# BayesianSearch: Testing config: {'topK': 800, 'add_zeros_quota': 0.38009173827507636, 'normalize_similarity': True}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8196.22 column/sec, elapsed time 0.13 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 6.73E-04, nonzero cells 2853774
# CFW_D_Similarity_Linalg: Generating train data. Sample 1184107 ( 57.26 %)
# CFW_D_Similarity_Linalg: Content S structure has 646097 out of 2853774 ( 22.64%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.92E+06, average is: 6.07E+00, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 2910.95 column/sec, elapsed time 0.37 min
# SequentialEvaluator: Processed 27001 ( 38.65% ) in 30.18 seconds. Users per second: 895
# SequentialEvaluator: Processed 56001 ( 80.17% ) in 60.91 seconds. Users per second: 919
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 75.01 seconds. Users per second: 931
# BayesianSearch: Config is suboptimal. Config: {'topK': 800, 'add_zeros_quota': 0.38009173827507636, 'normalize_similarity': True, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.02059445247672627, 'PRECISION': 0.00969933817178923, 'RECALL': 0.0016942935632998503, 'RECALL_TEST_LEN': 0.00969933817178923, 'MAP': 0.004405209531216943, 'MRR': 0.020701814659471286, 'NDCG': 0.0017849015533740248, 'F1': 0.002884686220306829, 'HIT_RATE': 0.048184147615843796, 'ARHR': 0.021312586187974755, 'NOVELTY': 0.001096712609973419, 'DIVERSITY_MEAN_INTER_LIST': 0.8465851094629667, 'DIVERSITY_HERFINDAHL': 0.9693145981265872, 'COVERAGE_ITEM': 0.02520956796757454, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.048351961089522846, 'SHANNON_ENTROPY': 6.157188492481505}
#
#     2 | 04m05s |    0.00441 |            0.3801 |                 0.2698 |   11.7663 |
# BayesianSearch: Testing config: {'topK': 600, 'add_zeros_quota': 0.05176644703066691, 'normalize_similarity': True}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8228.27 column/sec, elapsed time 0.13 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 5.89E-04, nonzero cells 2499662
# CFW_D_Similarity_Linalg: Generating train data. Sample 594418 ( 25.01 %)
# CFW_D_Similarity_Linalg: Content S structure has 578522 out of 2499662 ( 23.14%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.53E+06, average is: 6.10E+00, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 3218.35 column/sec, elapsed time 0.34 min
# SequentialEvaluator: Processed 29001 ( 41.51% ) in 30.23 seconds. Users per second: 959
# SequentialEvaluator: Processed 58001 ( 83.03% ) in 60.41 seconds. Users per second: 960
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 71.93 seconds. Users per second: 971
# BayesianSearch: Config is suboptimal. Config: {'topK': 600, 'add_zeros_quota': 0.05176644703066691, 'normalize_similarity': True, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.016221232899590113, 'PRECISION': 0.007397254391113004, 'RECALL': 0.0013590164218846461, 'RECALL_TEST_LEN': 0.007397254391113004, 'MAP': 0.0034095763885906055, 'MRR': 0.016252725806528836, 'NDCG': 0.0013664665433071297, 'F1': 0.0022961807392842177, 'HIT_RATE': 0.0367608113718024, 'ARHR': 0.016615132818949465, 'NOVELTY': 0.001130608325510885, 'DIVERSITY_MEAN_INTER_LIST': 0.8792430157580405, 'DIVERSITY_HERFINDAHL': 0.9758460858862925, 'COVERAGE_ITEM': 0.028188043111124758, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.05351828269070927, 'SHANNON_ENTROPY': 6.5155959298829185}
#
#     3 | 03m02s |    0.00341 |            0.0518 |                 0.0056 |    9.8201 |
# BayesianSearch: Testing config: {'topK': 300, 'add_zeros_quota': 0.32839844435750476, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7875.97 column/sec, elapsed time 0.14 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 3.72E-04, nonzero cells 1576400
# CFW_D_Similarity_Linalg: Content S structure has 391759 out of 1576400 ( 24.85%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 2.15E+04, average is: 5.48E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 8241.45 column/sec, elapsed time 0.13 min
# SequentialEvaluator: Processed 29001 ( 41.51% ) in 30.58 seconds. Users per second: 948
# SequentialEvaluator: Processed 60001 ( 85.89% ) in 60.67 seconds. Users per second: 989
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 69.58 seconds. Users per second: 1004
# BayesianSearch: Config is suboptimal. Config: {'topK': 300, 'add_zeros_quota': 0.32839844435750476, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.22182935616091967, 'PRECISION': 0.11966636605251318, 'RECALL': 0.024743930734398335, 'RECALL_TEST_LEN': 0.11966636605251318, 'MAP': 0.06997291689530447, 'MRR': 0.23365708995999748, 'NDCG': 0.04797324648429329, 'F1': 0.041008381517416995, 'HIT_RATE': 0.5953734056715863, 'ARHR': 0.28566619427308815, 'NOVELTY': 0.0007018729924844246, 'DIVERSITY_MEAN_INTER_LIST': 0.7770335796612085, 'DIVERSITY_HERFINDAHL': 0.9554044912916769, 'COVERAGE_ITEM': 0.019836030337458163, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.04127973684745727, 'SHANNON_ENTROPY': 5.579810643928271}
#
#     4 | 02m43s |    0.06997 |            0.3284 |                 0.9144 |    6.5349 |
# BayesianSearch: Testing config: {'topK': 50, 'add_zeros_quota': 0.8760636327595164, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8167.18 column/sec, elapsed time 0.13 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 7.86E-05, nonzero cells 333650
# CFW_D_Similarity_Linalg: Content S structure has 102067 out of 333650 ( 30.59%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 5.75E+03, average is: 5.63E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 8763.21 column/sec, elapsed time 0.12 min
# SequentialEvaluator: Processed 34817 ( 49.84% ) in 30.00 seconds. Users per second: 1161
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 59.88 seconds. Users per second: 1167
# BayesianSearch: New best config found. Config: {'topK': 50, 'add_zeros_quota': 0.8760636327595164, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.23544049510667026, 'PRECISION': 0.12604200962916262, 'RECALL': 0.026032438217853525, 'RECALL_TEST_LEN': 0.12604200962916262, 'MAP': 0.07517644775915006, 'MRR': 0.2480426681172772, 'NDCG': 0.05034221382832205, 'F1': 0.04315229645714153, 'HIT_RATE': 0.6273673361295218, 'ARHR': 0.3052275839691781, 'NOVELTY': 0.0007159127261766533, 'DIVERSITY_MEAN_INTER_LIST': 0.9091884729822812, 'DIVERSITY_HERFINDAHL': 0.98183509159755, 'COVERAGE_ITEM': 0.02645315810483004, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.061951028430070616, 'SHANNON_ENTROPY': 6.7985030108162645}
#
# BayesianSearch: Saving model in result_experiments/
#
# CFW_D_Similarity_Linalg: Saving model in file 'result_experiments/_best_model'
# CFW_D_Similarity_Linalg: Saving complete
# CFW_D_Similarity_Linalg: Loading model from file 'result_experiments/_best_model'
# CFW_D_Similarity_Linalg: Loading complete
# SequentialEvaluator: Processed 33376 ( 47.76% ) in 30.00 seconds. Users per second: 1113
# SequentialEvaluator: Processed 67248 ( 96.24% ) in 60.00 seconds. Users per second: 1121
# SequentialEvaluator: Processed 69878 ( 100.00% ) in 61.89 seconds. Users per second: 1129
# BayesianSearch: Best result evaluated on URM_test. Config: {'topK': 50, 'add_zeros_quota': 0.8760636327595164, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: CUTOFF: 5 - ROC_AUC: 0.3506301, PRECISION: 0.2503077, RECALL: 0.0259702, RECALL_TEST_LEN: 0.2503077, MAP: 0.1756062, MRR: 0.4140521, NDCG: 0.0640900, F1: 0.0470580, HIT_RATE: 1.2515241, ARHR: 0.6031607, NOVELTY: 0.0007159, DIVERSITY_MEAN_INTER_LIST: 0.9092023, DIVERSITY_HERFINDAHL: 0.9818379, COVERAGE_ITEM: 0.0264532, COVERAGE_USER: 0.9763861, DIVERSITY_GINI: 0.0619704, SHANNON_ENTROPY: 6.7989000,
#
#
#     5 | 02m52s |    0.07518 |            0.8761 |                 0.9956 |    3.1706 |
# Bayesian Optimization
# --------------------------------------------------------------------------------------
#  Step |   Time |      Value |   add_zeros_quota |   normalize_similarity |      topK |
# BayesianSearch: Testing config: {'topK': 5, 'add_zeros_quota': 0.0, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8579.68 column/sec, elapsed time 0.13 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 8.64E-06, nonzero cells 36670
# CFW_D_Similarity_Linalg: Content S structure has 13028 out of 36670 ( 35.53%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 7.68E+02, average is: 5.90E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 8445.91 column/sec, elapsed time 0.13 min
# SequentialEvaluator: Processed 41526 ( 59.44% ) in 30.00 seconds. Users per second: 1384
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 49.96 seconds. Users per second: 1398
# BayesianSearch: Config is suboptimal. Config: {'topK': 5, 'add_zeros_quota': 0.0, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.15160494534072014, 'PRECISION': 0.07390144628787162, 'RECALL': 0.01456770479374473, 'RECALL_TEST_LEN': 0.07390144628787162, 'MAP': 0.040785759957241825, 'MRR': 0.15206350115235964, 'NDCG': 0.025775536039067255, 'F1': 0.024337849751927945, 'HIT_RATE': 0.36785146799891205, 'ARHR': 0.17580509707928837, 'NOVELTY': 0.0007965822853647887, 'DIVERSITY_MEAN_INTER_LIST': 0.955702387580188, 'DIVERSITY_HERFINDAHL': 0.9911377413481873, 'COVERAGE_ITEM': 0.04234347652531704, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.09823789408179645, 'SHANNON_ENTROPY': 8.151482499344475}
#
#     6 | 01m15s |    0.04079 |            0.0000 |                 1.0000 |    0.0000 |
# BayesianSearch: Testing config: {'topK': 200, 'add_zeros_quota': 0.9999999999999999, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 8790.31 column/sec, elapsed time 0.12 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 2.66E-04, nonzero cells 1130194
# CFW_D_Similarity_Linalg: Content S structure has 295136 out of 1130194 ( 26.11%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 1.63E+04, average is: 5.52E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 8680.75 column/sec, elapsed time 0.13 min
# SequentialEvaluator: Processed 31001 ( 44.38% ) in 30.16 seconds. Users per second: 1028
# SequentialEvaluator: Processed 62915 ( 90.06% ) in 60.16 seconds. Users per second: 1046
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 66.91 seconds. Users per second: 1044
# BayesianSearch: Config is suboptimal. Config: {'topK': 200, 'add_zeros_quota': 0.9999999999999999, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.22847746109910178, 'PRECISION': 0.12388903999118378, 'RECALL': 0.025772877732134162, 'RECALL_TEST_LEN': 0.12388903999118378, 'MAP': 0.07293869778420074, 'MRR': 0.2416777607589137, 'NDCG': 0.04973412947752327, 'F1': 0.042669199067021976, 'HIT_RATE': 0.6165022832357531, 'ARHR': 0.2967154329559184, 'NOVELTY': 0.0007008543121245612, 'DIVERSITY_MEAN_INTER_LIST': 0.8073510773408967, 'DIVERSITY_HERFINDAHL': 0.9614679040288753, 'COVERAGE_ITEM': 0.020649737464304357, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.04287572738543509, 'SHANNON_ENTROPY': 5.74188191667359}
#
#     7 | 02m49s |    0.07294 |            1.0000 |                 1.0000 |    5.9695 |
# BayesianSearch: Best config is: Config {'topK': 50, 'add_zeros_quota': 0.8760636327595164, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0}, MAP value is 0.0752

# %% [markdown]
# ### The best solution has a MAP of 0.1756062, slightly better than the pure CBF
#
# ### Let's try another ICM, the genres of the movie

# %%
genres_path = dataFile.extract("ml-10M100K/movies.dat", path = "data/Movielens_10M")


def _loadICM_genres(genres_path, header=True, separator='::', genresSeparator="|"):

    # Genres
    from data.IncrementalSparseMatrix import IncrementalSparseMatrix

    ICM_builder = IncrementalSparseMatrix(auto_create_col_mapper = True, 
                                          auto_create_row_mapper = False)


    fileHandle = open(genres_path, "r", encoding="latin1")
    numCells = 0

    if header:
        fileHandle.readline()

    for line in fileHandle:
        numCells += 1
        if (numCells % 1000000 == 0):
            print("Processed {} cells".format(numCells))

        if (len(line)) > 1:
            line = line.split(separator)

            line[-1] = line[-1].replace("\n", "")

            movie_id = int(line[0])

            title = line[1]
            # In case the title contains commas, it is enclosed in "..."
            # genre list will always be the last element
            genreList = line[-1]

            genreList = genreList.split(genresSeparator)

            # Rows movie ID
            # Cols features
            ICM_builder.add_single_row(movie_id, genreList, data = 1.0)


    fileHandle.close()

    return ICM_builder.get_SparseMatrix(), ICM_builder.get_column_token_to_id_mapper(), ICM_builder.get_row_token_to_id_mapper()


ICM_genres, _, _ = _loadICM_genres(genres_path, header=True, separator='::', genresSeparator="|")
ICM_genres = ICM_genres.tocsr()

ICM_genres
# Out:
# <65134x20 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21559 stored elements in Compressed Sparse Row format>

# %%
CFW_weithing_genre = CFW_D_Similarity_Linalg(URM_train, ICM_genres, W_sparse_CF)
CFW_weithing_genre.fit()

results_dict, _ = evaluator_test.evaluateRecommender(CFW_weithing_genre)
results_dict
# Out:
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7304.08 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 7.54E-04, nonzero cells 3199152
# CFW_D_Similarity_Linalg: Content S structure has 343180 out of 3199152 ( 10.73%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 1.52E+04, average is: 4.43E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7440.28 column/sec, elapsed time 0.15 min
# SequentialEvaluator: Processed 33001 ( 47.23% ) in 30.22 seconds. Users per second: 1092
# SequentialEvaluator: Processed 67001 ( 95.88% ) in 60.71 seconds. Users per second: 1104
# SequentialEvaluator: Processed 69878 ( 100.00% ) in 62.66 seconds. Users per second: 1115
# {5: {'ROC_AUC': 0.062148792657679544,
#   'PRECISION': 0.032264804373338514,
#   'RECALL': 0.002480477801986029,
#   'RECALL_TEST_LEN': 0.032264804373338514,
#   'MAP': 0.01579891620634061,
#   'MRR': 0.06194820496675068,
#   'NDCG': 0.004418842092226786,
#   'F1': 0.004606791254688688,
#   'HIT_RATE': 0.16132402186668193,
#   'ARHR': 0.06979759962601224,
#   'NOVELTY': 0.00105580196102687,
#   'DIVERSITY_MEAN_INTER_LIST': 0.9819069472755356,
#   'DIVERSITY_HERFINDAHL': 0.9963785791086539,
#   'COVERAGE_ITEM': 0.07697976479258145,
#   'COVERAGE_USER': 0.9763860943438408,
#   'DIVERSITY_GINI': 0.12912814834069017,
#   'SHANNON_ENTROPY': 9.410897424148793}}

# %%
from ParameterTuning.BayesianSearch import BayesianSearch
from ParameterTuning.AbstractClassSearch import DictionaryKeys

from ParameterTuning.AbstractClassSearch import EvaluatorWrapper


evaluator_validation_tuning = EvaluatorWrapper(evaluator_validation)
evaluator_test_tuning = EvaluatorWrapper(evaluator_test)


recommender_class = CFW_D_Similarity_Linalg

parameterSearch = BayesianSearch(recommender_class,
                                 evaluator_validation=evaluator_validation_tuning,
                                 evaluator_test=evaluator_test_tuning)


hyperparamethers_range_dictionary = {}
hyperparamethers_range_dictionary["topK"] = [5, 10, 20, 50, 100, 150, 200, 300, 400, 500, 600, 700, 800]
hyperparamethers_range_dictionary["add_zeros_quota"] = range(0,1)
hyperparamethers_range_dictionary["normalize_similarity"] = [True, False]



recommenderDictionary = {DictionaryKeys.CONSTRUCTOR_POSITIONAL_ARGS: [URM_train, ICM_genres, W_sparse_CF],
                         DictionaryKeys.CONSTRUCTOR_KEYWORD_ARGS: {},
                         DictionaryKeys.FIT_POSITIONAL_ARGS: dict(),
                         DictionaryKeys.FIT_KEYWORD_ARGS: dict(),
                         DictionaryKeys.FIT_RANGE_KEYWORD_ARGS: hyperparamethers_range_dictionary}


output_root_path = "result_experiments/ICM_genres/"

import os

# If directory does not exist, create
if not os.path.exists(output_root_path):
    os.makedirs(output_root_path)

    
output_root_path += recommender_class.RECOMMENDER_NAME      
    
n_cases = 2
metric_to_optimize = "MAP"

best_parameters_CFW_D = parameterSearch.search(recommenderDictionary,
                                                 n_cases = n_cases,
                                                 output_root_path = output_root_path,
                                                 metric=metric_to_optimize)
# Out:
# Initialization
# --------------------------------------------------------------------------------------
#  Step |   Time |      Value |   add_zeros_quota |   normalize_similarity |      topK |
# BayesianSearch: Testing config: {'topK': 50, 'add_zeros_quota': 0.5460399111630392, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7442.35 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 1.26E-04, nonzero cells 533928
# CFW_D_Similarity_Linalg: Content S structure has 65514 out of 533928 ( 12.27%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.02E+03, average is: 4.60E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7324.09 column/sec, elapsed time 0.15 min
# SequentialEvaluator: Processed 38948 ( 55.75% ) in 30.00 seconds. Users per second: 1298
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 53.91 seconds. Users per second: 1296
# BayesianSearch: New best config found. Config: {'topK': 50, 'add_zeros_quota': 0.5460399111630392, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.04233768030882133, 'PRECISION': 0.019541825920573092, 'RECALL': 0.002923853014383998, 'RECALL_TEST_LEN': 0.019541825920573092, 'MAP': 0.009481341247914655, 'MRR': 0.04089664123375849, 'NDCG': 0.004327835108402573, 'F1': 0.005086641431123445, 'HIT_RATE': 0.09744191705913509, 'ARHR': 0.04394143273639938, 'NOVELTY': 0.0010364723459785942, 'DIVERSITY_MEAN_INTER_LIST': 0.9838253076530643, 'DIVERSITY_HERFINDAHL': 0.9967622448470803, 'COVERAGE_ITEM': 0.06462062824331379, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.17520149629050483, 'SHANNON_ENTROPY': 9.674670809271444}
#
# BayesianSearch: Saving model in result_experiments/ICM_genres/
#
# CFW_D_Similarity_Linalg: Saving model in file 'result_experiments/ICM_genres/_best_model'
# CFW_D_Similarity_Linalg: Saving complete
# CFW_D_Similarity_Linalg: Loading model from file 'result_experiments/ICM_genres/_best_model'
# CFW_D_Similarity_Linalg: Loading complete
# SequentialEvaluator: Processed 37001 ( 52.95% ) in 30.10 seconds. Users per second: 1229
# SequentialEvaluator: Processed 69878 ( 100.00% ) in 54.94 seconds. Users per second: 1272
# BayesianSearch: Best result evaluated on URM_test. Config: {'topK': 50, 'add_zeros_quota': 0.5460399111630392, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: CUTOFF: 5 - ROC_AUC: 0.0758334, PRECISION: 0.0392026, RECALL: 0.0029488, RECALL_TEST_LEN: 0.0392026, MAP: 0.0204536, MRR: 0.0769627, NDCG: 0.0055672, F1: 0.0054849, HIT_RATE: 0.1960131, ARHR: 0.0884196, NOVELTY: 0.0010365, DIVERSITY_MEAN_INTER_LIST: 0.9838275, DIVERSITY_HERFINDAHL: 0.9967627, COVERAGE_ITEM: 0.0646206, COVERAGE_USER: 0.9763861, DIVERSITY_GINI: 0.1752086, SHANNON_ENTROPY: 9.6748105,
#
#
#     1 | 02m14s |    0.00948 |            0.5460 |                 0.7785 |    2.9236 |
# BayesianSearch: Testing config: {'topK': 300, 'add_zeros_quota': 0.9818092972417922, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7389.16 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 7.54E-04, nonzero cells 3199152
# CFW_D_Similarity_Linalg: Content S structure has 343180 out of 3199152 ( 10.73%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 1.52E+04, average is: 4.43E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7043.79 column/sec, elapsed time 0.15 min
# SequentialEvaluator: Processed 33001 ( 47.24% ) in 30.04 seconds. Users per second: 1099
# SequentialEvaluator: Processed 67001 ( 95.91% ) in 60.16 seconds. Users per second: 1114
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 62.06 seconds. Users per second: 1126
# BayesianSearch: Config is suboptimal. Config: {'topK': 300, 'add_zeros_quota': 0.9818092972417922, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.031187521174208276, 'PRECISION': 0.015442976366006009, 'RECALL': 0.0022998228659914257, 'RECALL_TEST_LEN': 0.015442976366006009, 'MAP': 0.006873255364530581, 'MRR': 0.03019334736199182, 'NDCG': 0.003083033222764459, 'F1': 0.004003439333457135, 'HIT_RATE': 0.07704310233763259, 'ARHR': 0.03216666428084033, 'NOVELTY': 0.0010484862796817551, 'DIVERSITY_MEAN_INTER_LIST': 0.9748942082494275, 'DIVERSITY_HERFINDAHL': 0.994976050536015, 'COVERAGE_ITEM': 0.07334111216875978, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.1108203529553254, 'SHANNON_ENTROPY': 9.013769641884808}
#
#     2 | 01m48s |    0.00687 |            0.9818 |                 0.9002 |    7.2822 |
# BayesianSearch: Testing config: {'topK': 100, 'add_zeros_quota': 0.5408037722416156, 'normalize_similarity': True}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7548.72 column/sec, elapsed time 0.14 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 2.52E-04, nonzero cells 1067828
# CFW_D_Similarity_Linalg: Content S structure has 127182 out of 1067828 ( 11.91%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 1.61E+04, average is: 1.26E-01, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 3064.32 column/sec, elapsed time 0.35 min
# SequentialEvaluator: Processed 37001 ( 52.97% ) in 30.27 seconds. Users per second: 1222
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 55.67 seconds. Users per second: 1255
# BayesianSearch: Config is suboptimal. Config: {'topK': 100, 'add_zeros_quota': 0.5408037722416156, 'normalize_similarity': True, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.03446445357420634, 'PRECISION': 0.01577222039308997, 'RECALL': 0.0023044971055562143, 'RECALL_TEST_LEN': 0.01577222039308997, 'MAP': 0.00769780885714169, 'MRR': 0.0333414451426962, 'NDCG': 0.0033392181536924413, 'F1': 0.0040214199560061345, 'HIT_RATE': 0.07863206264225489, 'ARHR': 0.03575470842816976, 'NOVELTY': 0.0010813311116455071, 'DIVERSITY_MEAN_INTER_LIST': 0.989816524259286, 'DIVERSITY_HERFINDAHL': 0.9979604710155222, 'COVERAGE_ITEM': 0.0855467190714527, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.16316928961188898, 'SHANNON_ENTROPY': 10.05444038952249}
#
#     3 | 01m36s |    0.00770 |            0.5408 |                 0.2024 |    4.2721 |
# BayesianSearch: Testing config: {'topK': 700, 'add_zeros_quota': 0.02591915073946116, 'normalize_similarity': True}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7334.40 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 1.73E-03, nonzero cells 7331808
# CFW_D_Similarity_Linalg: Generating train data. Sample 624340 ( 8.74 %)
# CFW_D_Similarity_Linalg: Content S structure has 705850 out of 7331808 ( 9.63%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 7.84E+04, average is: 1.11E-01, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 3133.95 column/sec, elapsed time 0.35 min
# SequentialEvaluator: Processed 30001 ( 42.95% ) in 30.35 seconds. Users per second: 989
# SequentialEvaluator: Processed 60001 ( 85.89% ) in 60.38 seconds. Users per second: 994
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 69.39 seconds. Users per second: 1007
# BayesianSearch: Config is suboptimal. Config: {'topK': 700, 'add_zeros_quota': 0.02591915073946116, 'normalize_similarity': True, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.03521718176656118, 'PRECISION': 0.016675971389172612, 'RECALL': 0.0023562633893919223, 'RECALL_TEST_LEN': 0.016675971389172612, 'MAP': 0.008000617929007574, 'MRR': 0.03389925132771226, 'NDCG': 0.003454565540612396, 'F1': 0.004129097956600361, 'HIT_RATE': 0.08318421919063229, 'ARHR': 0.036735283030571726, 'NOVELTY': 0.0010870922586515988, 'DIVERSITY_MEAN_INTER_LIST': 0.9921662375152077, 'DIVERSITY_HERFINDAHL': 0.9984304069394974, 'COVERAGE_ITEM': 0.13321767433291368, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.20589119134999923, 'SHANNON_ENTROPY': 10.876395364725553}
#
#     4 | 02m14s |    0.00800 |            0.0259 |                 0.0021 |   11.3005 |
# BayesianSearch: Testing config: {'topK': 5, 'add_zeros_quota': 0.35747392814147605, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7459.88 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 1.26E-05, nonzero cells 53395
# CFW_D_Similarity_Linalg: Content S structure has 6812 out of 53395 ( 12.76%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.17E+02, average is: 4.66E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7629.74 column/sec, elapsed time 0.14 min
# SequentialEvaluator: Processed 45001 ( 64.42% ) in 30.34 seconds. Users per second: 1483
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 46.54 seconds. Users per second: 1501
# BayesianSearch: Config is suboptimal. Config: {'topK': 5, 'add_zeros_quota': 0.35747392814147605, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.03925399983776381, 'PRECISION': 0.016944376846034545, 'RECALL': 0.002331466482678726, 'RECALL_TEST_LEN': 0.016944376846034545, 'MAP': 0.008698440305831322, 'MRR': 0.03727829709263195, 'NDCG': 0.00381478761590069, 'F1': 0.004098938346065516, 'HIT_RATE': 0.08451551025666719, 'ARHR': 0.040173974452571995, 'NOVELTY': 0.000997128748647216, 'DIVERSITY_MEAN_INTER_LIST': 0.98014424759261, 'DIVERSITY_HERFINDAHL': 0.9960260433738333, 'COVERAGE_ITEM': 0.050879724874873335, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.14320690937018915, 'SHANNON_ENTROPY': 9.078284285883765}
#
#     5 | 01m08s |    0.00870 |            0.3575 |                 0.9678 |    0.0298 |
# /home/maurizio/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:357: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# Bayesian Optimization
# --------------------------------------------------------------------------------------
#  Step |   Time |      Value |   add_zeros_quota |   normalize_similarity |      topK |
# BayesianSearch: Testing config: {'topK': 200, 'add_zeros_quota': 0.0008248131146192383, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7253.56 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 5.03E-04, nonzero cells 2134992
# CFW_D_Similarity_Linalg: Content S structure has 237124 out of 2134992 ( 11.11%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 1.06E+04, average is: 4.48E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7353.67 column/sec, elapsed time 0.15 min
# SequentialEvaluator: Processed 35001 ( 50.10% ) in 30.12 seconds. Users per second: 1162
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 59.92 seconds. Users per second: 1166
# BayesianSearch: Config is suboptimal. Config: {'topK': 200, 'add_zeros_quota': 0.0008248131146192383, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.03496786291996505, 'PRECISION': 0.016308554141557182, 'RECALL': 0.0024266475011878717, 'RECALL_TEST_LEN': 0.016308554141557182, 'MAP': 0.007736141132758693, 'MRR': 0.03359816005077042, 'NDCG': 0.0034373887727751932, 'F1': 0.004224679606896225, 'HIT_RATE': 0.0813662195628212, 'ARHR': 0.03599782412642966, 'NOVELTY': 0.0010698046195956453, 'DIVERSITY_MEAN_INTER_LIST': 0.9857632531671877, 'DIVERSITY_HERFINDAHL': 0.9971498284015834, 'COVERAGE_ITEM': 0.0780084134246323, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.141265925735498, 'SHANNON_ENTROPY': 9.648111513319172}
#
#     6 | 01m38s |    0.00774 |            0.0008 |                 0.9995 |    6.2202 |
# BayesianSearch: Testing config: {'topK': 800, 'add_zeros_quota': 0.02399731634800717, 'normalize_similarity': False}
# CFW_D_Similarity_Linalg: Generating train data
# Similarity column 65134 ( 100 % ), 7272.10 column/sec, elapsed time 0.15 min
# CFW_D_Similarity_Linalg: Collaborative S density: 1.65E-03, nonzero cells 6997140
# CFW_D_Similarity_Linalg: Content S density: 1.97E-03, nonzero cells 8339369
# CFW_D_Similarity_Linalg: Generating train data. Sample 621450 ( 7.63 %)
# CFW_D_Similarity_Linalg: Content S structure has 800064 out of 8339369 ( 9.59%) nonzero collaborative cells
# CFW_D_Similarity_Linalg: Nonzero collaborative cell sum is: 3.48E+04, average is: 4.35E-02, average over all collaborative data is 3.96E-02
# Similarity column 65134 ( 100 % ), 7314.48 column/sec, elapsed time 0.15 min
# SequentialEvaluator: Processed 29756 ( 42.60% ) in 30.00 seconds. Users per second: 992
# SequentialEvaluator: Processed 60001 ( 85.89% ) in 60.67 seconds. Users per second: 989
# SequentialEvaluator: Processed 69857 ( 100.00% ) in 69.74 seconds. Users per second: 1002
# BayesianSearch: Config is suboptimal. Config: {'topK': 800, 'add_zeros_quota': 0.02399731634800717, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0} - results: {'ROC_AUC': 0.02658526227388332, 'PRECISION': 0.012570441521012696, 'RECALL': 0.0019829462308329484, 'RECALL_TEST_LEN': 0.012570441521012696, 'MAP': 0.005496971591171284, 'MRR': 0.024882736638179963, 'NDCG': 0.002562041419069345, 'F1': 0.0034255267651804255, 'HIT_RATE': 0.0626279399344375, 'ARHR': 0.026109289930381644, 'NOVELTY': 0.0010744912400444237, 'DIVERSITY_MEAN_INTER_LIST': 0.966049075478326, 'DIVERSITY_HERFINDAHL': 0.993207049305335, 'COVERAGE_ITEM': 0.06432892191482176, 'COVERAGE_USER': 0.9760926671137938, 'DIVERSITY_GINI': 0.09425795691082968, 'SHANNON_ENTROPY': 8.597589369468878}
#
#     7 | 02m12s |    0.00550 |            0.0240 |                 0.9907 |   11.9593 |
# /home/maurizio/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-8.3431562e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 7, 'warnflag': 2}
#   ConvergenceWarning)
# /home/maurizio/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([1.17750328e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 54, 'nit': 7, 'warnflag': 2}
#   ConvergenceWarning)
# /home/maurizio/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:357: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# BayesianSearch: Best config is: Config {'topK': 50, 'add_zeros_quota': 0.5460399111630392, 'normalize_similarity': False, 'epochs': 0, 'max_epochs': 0}, MAP value is 0.0095

# %% [markdown]
# ### Here the best solution has a MAP of 0.0204536... not great

# %% [markdown]
# ### Since we are weighting features, and weights can be applied only to common features, we expect a sparse ICM to have limited quality gains, whereas a more dense one to exhibit much higher improvements.
#
# ## This however greatly depends on the ICM structure...
#
# ## Tip:
# ### If your ICM is very sparse, you may try to aggregate features (e.g., put them in OR, add them...) to reduce their number and get a new denser ICM on which to try feature weighting
